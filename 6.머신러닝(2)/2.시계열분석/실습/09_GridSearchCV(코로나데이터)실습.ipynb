# %% [markdown]
# # GridSearchCV 적용 (Covid19 확진자 데이터)
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import pandas as pd
print(pd.__version__)
from pandas import DataFrame
# Out:
# 2.2.1

# %%
import warnings
warnings.filterwarnings(action="ignore")

from hossam.util import *
from hossam.plot import *
from hossam.timeserise import *

import seaborn as sb
from matplotlib import pyplot as plt
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot


from pandas import to_datetime, DatetimeIndex, Series, date_range, concat

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import ParameterGrid

import concurrent.futures as futures
from sklearn.metrics import mean_squared_error
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = my_read_excel("https://data.hossam.kr/tsdata/covid19_seoul_230531.xlsx")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   서울시 기준일            1212 non-null   object
#  1   서울시 확진자            1212 non-null   int64
#  2   서울시 추가 확진          1211 non-null   float64
#  3   서울시 치료중            1212 non-null   int64
#  4   서울시 퇴원             770 non-null    float64
#  5   서울시 추가 퇴원          770 non-null    float64
#  6   서울시 사망             1212 non-null   int64
#  7   서울시 의심환자 전체        187 non-null    float64
#  8   서울시 의심환자 검사중       188 non-null    float64
#  9   서울시 의심환자 검사결과(음성)  188 non-null    float64
#  10  전국 기준일             1212 non-null   object
#  11  전국 확진              1212 non-null   float64
#  12  전국 추가 확진           1211 non-null   float64
#  13  전국 치료중             1212 non-null   int64
#  14  전국 퇴원              770 non-null    float64
#  15  전국 사망              1212 non-null   int64
#  16  전국 의심환자 전체         187 non-null    float64
#  17  전국 의심환자 검사중        188 non-null    float64
#  18  전국 의심환자 검사결과(음성)   188 non-null    float64
#  19  자가격리자 해외입국자 감시중    188 non-null    float64
#  20  자가격리자 해외입국자 감시해제   188 non-null    float64
#  21  자가격리자 접촉자 감시중      188 non-null    float64
#  22  자가격리자 접촉자 감시해제     188 non-null    float64
#  23  확인중 확진자            1200 non-null   float64
#  24  서울시 당일사망자          458 non-null    float64
#  25  전국 당일 사망자          458 non-null    float64
# dtypes: float64(19), int64(5), object(2)
# memory usage: 246.3+ KB
# None
#
# 데이터프레임 상위 5개 행
# +----+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------+
# |    | 서울시 기준일   |   서울시 확진자 |   서울시 추가 확진 |   서울시 치료중 |   서울시 퇴원 |   서울시 추가 퇴원 |   서울시 사망 |   서울시 의심환자 전체 |   서울시 의심환자 검사중 |   서울시 의심환자 검사결과(음성) | 전국 기준일   |   전국 확진 |   전국 추가 확진 |   전국 치료중 |   전국 퇴원 |   전국 사망 |   전국 의심환자 전체 |   전국 의심환자 검사중 |   전국 의심환자 검사결과(음성) |   자가격리자 해외입국자 감시중 |   자가격리자 해외입국자 감시해제 |   자가격리자 접촉자 감시중 |   자가격리자 접촉자 감시해제 |   확인중 확진자 |   서울시 당일사망자 |   전국 당일 사망자 |
# |----+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------|
# |  0 | 2023-05-31      |         6204277 |               5987 |               0 |           nan |                nan |          6492 |                    nan |                      nan |                              nan | 2023.05.31.00 | 3.17035e+07 |            24411 |             0 |         nan |       34784 |                  nan |                    nan |                            nan |                            nan |                              nan |                        nan |                          nan |               0 |                   6 |                 17 |
# |  1 | 2023-05-30      |         6198290 |               3326 |               0 |           nan |                nan |          6486 |                    nan |                      nan |                              nan | 2023.05.30.00 | 3.16791e+07 |            13529 |             0 |         nan |       34767 |                  nan |                    nan |                            nan |                            nan |                              nan |                        nan |                          nan |               0 |                   1 |                  7 |
# |  2 | 2023-05-29      |         6194964 |               1393 |               0 |           nan |                nan |          6485 |                    nan |                      nan |                              nan | 2023.05.29.00 | 3.16656e+07 |             6868 |             0 |         nan |       34760 |                  nan |                    nan |                            nan |                            nan |                              nan |                        nan |                          nan |               0 |                   1 |                  3 |
# |  3 | 2023-05-28      |         6194964 |               1393 |               0 |           nan |                nan |          6485 |                    nan |                      nan |                              nan | 2023.05.28.00 | 3.16656e+07 |             6868 |             0 |         nan |       34760 |                  nan |                    nan |                            nan |                            nan |                              nan |                        nan |                          nan |               0 |                   1 |                  3 |
# |  4 | 2023-05-27      |         6191196 |               4078 |               0 |           nan |                nan |          6485 |                    nan |                      nan |                              nan | 2023.05.27.00 | 3.16472e+07 |            17796 |             0 |         nan |       34784 |                  nan |                    nan |                            nan |                            nan |                              nan |                        nan |                          nan |               0 |                   0 |                  3 |
# +----+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------+
#
# 데이터프레임 하위 5개 행
# +------+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------+
# |      | 서울시 기준일   |   서울시 확진자 |   서울시 추가 확진 |   서울시 치료중 |   서울시 퇴원 |   서울시 추가 퇴원 |   서울시 사망 |   서울시 의심환자 전체 |   서울시 의심환자 검사중 |   서울시 의심환자 검사결과(음성) | 전국 기준일   |   전국 확진 |   전국 추가 확진 |   전국 치료중 |   전국 퇴원 |   전국 사망 |   전국 의심환자 전체 |   전국 의심환자 검사중 |   전국 의심환자 검사결과(음성) |   자가격리자 해외입국자 감시중 |   자가격리자 해외입국자 감시해제 |   자가격리자 접촉자 감시중 |   자가격리자 접촉자 감시해제 |   확인중 확진자 |   서울시 당일사망자 |   전국 당일 사망자 |
# |------+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------|
# | 1207 | 2020-02-09      |              10 |                  0 |              10 |             0 |                  0 |             0 |                    459 |                       45 |                              414 | 20.02.09.18   |          27 |                0 |            24 |           3 |           0 |                 2571 |                    888 |                           1683 |                              0 |                                0 |                          0 |                            0 |             nan |                 nan |                nan |
# | 1208 | 2020-02-08      |              10 |                  0 |              10 |             0 |                  0 |             0 |                    414 |                       92 |                              322 | 20.02.08.18   |          24 |                0 |            22 |           2 |           0 |                 1677 |                    620 |                           1057 |                              0 |                                0 |                          0 |                            0 |             nan |                 nan |                nan |
# | 1209 | 2020-02-07      |              10 |                  0 |              10 |             0 |                  0 |             0 |                    322 |                      115 |                              207 | 20.02.07.18   |          24 |                0 |            22 |           2 |           0 |                 1106 |                    264 |                            842 |                              0 |                                0 |                          0 |                            0 |             nan |                 nan |                nan |
# | 1210 | 2020-02-06      |              11 |                  0 |              11 |             0 |                  0 |             0 |                    192 |                       28 |                              164 | 20.02.06.09   |          24 |                0 |            23 |           1 |           0 |                  591 |                    169 |                            693 |                              0 |                                0 |                          0 |                            0 |               0 |                 nan |                nan |
# | 1211 | 2020-02-05      |               8 |                  0 |               8 |             0 |                  0 |             0 |                      0 |                       16 |                              148 | 20.02.05.15   |          18 |                0 |            18 |           0 |           0 |                  200 |                    174 |                            522 |                              0 |                                0 |                          0 |                            0 |               0 |                 nan |                nan |
# +------+-----------------+-----------------+--------------------+-----------------+---------------+--------------------+---------------+------------------------+--------------------------+----------------------------------+---------------+-------------+------------------+---------------+-------------+-------------+----------------------+------------------------+--------------------------------+--------------------------------+----------------------------------+----------------------------+------------------------------+-----------------+---------------------+--------------------+
#
# 기술통계
# +--------------------------------+---------+-------------+-------------+-------+---------+---------+-------------+-------------+-------+
# |                                |   count |        mean |         std |   min |     25% |     50% |         75% |         max |   nan |
# |--------------------------------+---------+-------------+-------------+-------+---------+---------+-------------+-------------+-------|
# | 서울시 확진자                  |    1212 | 1.84485e+06 | 2.80102e+06 |     8 | 9642.25 |  102572 | 3.99126e+06 | 5.38385e+07 |     0 |
# | 서울시 추가 확진               |    1211 |     5123.64 |     12099.4 |     0 |     120 |     659 |        4204 |      128375 |     1 |
# | 서울시 치료중                  |    1212 |     19170.7 |      100999 |     0 |       0 |     367 |      4070.5 | 1.22508e+06 |     0 |
# | 서울시 퇴원                    |     770 |     54033.9 |     76521.1 |     0 |    1571 |   24212 |     71734.5 |      374439 |   442 |
# | 서울시 추가 퇴원               |     770 |     572.857 |     1755.97 |     0 |      12 |     127 |      457.75 |       20838 |   442 |
# | 서울시 사망                    |    1212 |     2328.71 |     2504.24 |     0 |    96.5 |     654 |        4971 |        6492 |     0 |
# | 서울시 의심환자 전체           |     187 |      156142 |      117443 |     0 | 57726.5 |  123201 |      261775 |      364796 |  1025 |
# | 서울시 의심환자 검사중         |     188 |     6489.86 |     3194.62 |    13 |    4311 |  7107.5 |      8937.5 |       11202 |  1024 |
# | 서울시 의심환자 검사결과(음성) |     188 |      150840 |      115191 |   148 | 53834.2 |  117286 |      258658 |      354960 |  1024 |
# | 전국 확진                      |    1212 | 9.04408e+06 | 1.21488e+07 |    18 | 35035.2 |  312531 | 1.97209e+07 | 3.17035e+07 |     0 |
# | 전국 추가 확진                 |    1211 |     26162.9 |     61890.8 |     0 |   355.5 |    1940 |       20278 |      621266 |     1 |
# | 전국 치료중                    |    1212 |     74737.5 |      438204 |     0 |       0 |    1741 |      8944.5 | 5.46839e+06 |     0 |
# | 전국 퇴원                      |     770 |      178992 |      270194 |     0 | 13903.2 |   78722 |      229958 | 1.74927e+06 |   442 |
# | 전국 사망                      |    1212 |     11587.7 |     13290.3 |     0 |  534.25 |  2505.5 |     25084.5 |       34784 |     0 |
# | 전국 의심환자 전체             |     187 |      738726 |      504372 |   200 |  325979 |  644041 |  1.1898e+06 | 1.62465e+06 |  1025 |
# | 전국 의심환자 검사중           |     188 |     17049.7 |     7446.74 |   169 |   13748 | 18397.5 |     21588.2 |       35555 |  1024 |
# | 전국 의심환자 검사결과(음성)   |     188 |      726313 |      503194 |   522 |  313671 |  637606 | 1.17912e+06 | 1.59728e+06 |  1024 |
# | 자가격리자 해외입국자 감시중   |     188 |     5891.01 |     5180.46 |     0 |       0 |  7338.5 |     8344.25 |       23069 |  1024 |
# | 자가격리자 해외입국자 감시해제 |     188 |     34835.1 |     33143.3 |     0 |       0 |   32106 |     64239.2 |       97189 |  1024 |
# | 자가격리자 접촉자 감시중       |     188 |     1749.15 |     1534.76 |     0 |       0 |  2175.5 |     2962.25 |        5176 |  1024 |
# | 자가격리자 접촉자 감시해제     |     188 |     15148.3 |     12847.1 |     0 |       0 |   16102 |     26685.8 |       36421 |  1024 |
# | 확인중 확진자                  |    1200 |           0 |           0 |     0 |       0 |       0 |           0 |           0 |    12 |
# | 서울시 당일사망자              |     458 |     8.99563 |     12.5398 |     0 |       2 |       4 |          10 |          68 |   754 |
# | 전국 당일 사망자               |     458 |     52.1965 |     79.5801 |     0 |      11 |      27 |          55 |         470 |   754 |
# +--------------------------------+---------+-------------+-------------+-------+---------+---------+-------------+-------------+-------+

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 필요한 데이터만 추출

# %%
df = origin[['서울시 기준일', '서울시 추가 확진']]
my_pretty_table(df.head())
# Out:
# +----+-----------------+--------------------+
# |    | 서울시 기준일   |   서울시 추가 확진 |
# |----+-----------------+--------------------|
# |  0 | 2023-05-31      |               5987 |
# |  1 | 2023-05-30      |               3326 |
# |  2 | 2023-05-29      |               1393 |
# |  3 | 2023-05-28      |               1393 |
# |  4 | 2023-05-27      |               4078 |
# +----+-----------------+--------------------+

# %% [markdown]
# ### [2] 결측치 처리
#
# #### (1) 결측치 존재 확인

# %%
df.isna().sum()
# Out:
# 서울시 기준일      0
# 서울시 추가 확진    1
# dtype: int64

# %% [markdown]
# #### (2) 결측치 제거

# %%
df2 = df.fillna(0)
df2.isna().sum()
# Out:
# 서울시 기준일      0
# 서울시 추가 확진    0
# dtype: int64

# %% [markdown]
# ### [3] 날짜 타입에 대한 형변환
#
# ```python
# to_datetime(날짜필드, 형식문자열)
# ```

# %%
df2['서울시 기준일'] = to_datetime(df2['서울시 기준일'].str.strip(), format="%Y-%m-%d")
df2.dtypes
# Out:
# 서울시 기준일      datetime64[ns]
# 서울시 추가 확진           float64
# dtype: object

# %% [markdown]
# ### [3] 컬럼이름 변경, 정렬, 인덱스 재설정

# %%
df3 = df2.rename(columns={"서울시 기준일": "ds", "서울시 추가 확진": "y"})
df3.sort_values('ds', inplace=True)
df3.reset_index(drop=True, inplace=True)
my_pretty_table(df3.head())
# Out:
# +----+---------------------+-----+
# |    | ds                  |   y |
# |----+---------------------+-----|
# |  0 | 2020-02-05 00:00:00 |   0 |
# |  1 | 2020-02-06 00:00:00 |   0 |
# |  2 | 2020-02-07 00:00:00 |   0 |
# |  3 | 2020-02-08 00:00:00 |   0 |
# |  4 | 2020-02-09 00:00:00 |   0 |
# +----+---------------------+-----+

# %% [markdown]
# ## #03. 탐색적 데이터 분석
#
# ### [1] 날짜 컬럼을 인덱스로 설정

# %%
df4 = df3.set_index("ds")
df4.head()
# Out:
#               y
# ds
# 2020-02-05  0.0
# 2020-02-06  0.0
# 2020-02-07  0.0
# 2020-02-08  0.0
# 2020-02-09  0.0

# %% [markdown]
# ### [2] ACF, PACF 플롯

# %%
my_acf_pacf_plot(df4['y'], figsize=(20, 5))

# %% [markdown]
# ### [3] 성분 분해

# %%
my_seasonal_decompose(df4['y'], figsize=(20, 5))
# Out:
#             original        trend     seasonal        resid
# ds
# 2020-02-05       0.0          NaN  1343.186784          NaN
# 2020-02-06       0.0          NaN   763.326319          NaN
# 2020-02-07       0.0          NaN   186.890273          NaN
# 2020-02-08       0.0     0.000000   100.836008  -100.836008
# 2020-02-09       0.0     0.000000  -566.656973   566.656973
# ...              ...          ...          ...          ...
# 2023-05-27    4078.0  3450.571429   100.836008   526.592564
# 2023-05-28    1393.0  3547.000000  -566.656973 -1587.343027
# 2023-05-29    1393.0          NaN -2422.726006          NaN
# 2023-05-30    3326.0          NaN   595.143595          NaN
# 2023-05-31    5987.0          NaN  1343.186784          NaN
#
# [1212 rows x 4 columns]

# %% [markdown]
# ## #04. Prophet 분석 모델 구현
#
# ### [1] 튜닝하고자 하는 하이퍼 파라미터 정의

# %%
params = ParameterGrid({
    # 'growth': ['linear', 'logistic'],
    'changepoint_prior_scale': [0.01, 0.1, 1.0],
    'seasonality_prior_scale': [0.01, 0.1, 1.0],
    'seasonality_mode': ['additive', 'multiplicative'],
    'weekly_seasonality': [True, False],
    'daily_seasonality': [True, False],
    'yearly_seasonality': [True, False],
    
})

print('Total Possible Models', len(params))
# Out:
# Total Possible Models 144

# %% [markdown]
# ### [2] 훈련, 검증 데이터 분리

# %%
train, test = my_timeseries_split(df3)
train.shape, test.shape
# Out:
# ((969, 2), (243, 2))

# %% [markdown]
# ### [3] GridSearchCV 구성

# %%
# %%time
for p in params:
    m = Prophet(**p)
    m.fit(train)

    future = m.make_future_dataframe(periods=len(test), freq='D')
    forecast = m.predict(future)
    #my_pretty_table(forecast)

    pred = forecast[['ds', 'yhat']][-len(test):]
    score = np.sqrt(mean_squared_error(test['y'].values, pred['yhat'].values))
    print('RMSE --------------------------------------', score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'params' is not defined

# %% [markdown]
# #### (2) 비동기 처리 구현
#
# ##### 비동기 작업을 수행할 단위기능 함수를 정의

# %%
def covid19_prophet(train, **p):
    m = Prophet(**p)
    m.fit(train)

    future = m.make_future_dataframe(periods=len(test), freq='D')
    forecast = m.predict(future)

    pred = forecast[['ds', 'yhat']][-len(test):]
    score = np.sqrt(mean_squared_error(test['y'].values, pred['yhat'].values))

    return m, score, dict(p)

# %%
# %%time

result = []
processes = []

with futures.ThreadPoolExecutor() as executor:
    for p in params:
        processes.append(executor.submit(covid19_prophet, train, **p))

    for p in futures.as_completed(processes):
        m, score, p = p.result()
        result.append({
                "model": m, 
                "params": p,
                "score": score
        })

result_df = DataFrame(result).sort_values('score').reset_index(drop=True)
my_pretty_table(result_df)
# Out:
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:51 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:52 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:53 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:54 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:55 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:57 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:58 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] done processing
# 17:33:59 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:00 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:01 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:02 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:03 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:04 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:05 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:06 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:07 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:08 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:09 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:10 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:12 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:13 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] start processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:14 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:15 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:15 - cmdstanpy - INFO - Chain [1] done processing
# 17:34:15 - cmdstanpy - INFO - Chain [1] done processing
# +-----+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# |     | model                                                     | params                                                                                                                                                                                         |   score |
# |-----+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------|
# |   0 | <prophet.forecaster.Prophet object at 0x000001B5C74FDCD0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}     | 6252.07 |
# |   1 | <prophet.forecaster.Prophet object at 0x000001B5C76DA610> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}      | 7625.94 |
# |   2 | <prophet.forecaster.Prophet object at 0x000001B5C7382690> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}           | 11430.8 |
# |   3 | <prophet.forecaster.Prophet object at 0x000001B5C6495D10> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}           | 11477.7 |
# |   4 | <prophet.forecaster.Prophet object at 0x000001B5C7380950> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 11714.2 |
# |   5 | <prophet.forecaster.Prophet object at 0x000001B5C64F1590> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}            | 11785.4 |
# |   6 | <prophet.forecaster.Prophet object at 0x000001B5C4294910> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}            | 12201.2 |
# |   7 | <prophet.forecaster.Prophet object at 0x000001B5C6497890> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}           | 12261.5 |
# |   8 | <prophet.forecaster.Prophet object at 0x000001B5C730B250> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}           | 12717.3 |
# |   9 | <prophet.forecaster.Prophet object at 0x000001B5C6F12C90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 13089.4 |
# |  10 | <prophet.forecaster.Prophet object at 0x000001B5C6F2FD50> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 13111.8 |
# |  11 | <prophet.forecaster.Prophet object at 0x000001B5C7380390> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 13324.3 |
# |  12 | <prophet.forecaster.Prophet object at 0x000001B5C64D87D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}         | 15220.1 |
# |  13 | <prophet.forecaster.Prophet object at 0x000001B5C64561D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 15282.1 |
# |  14 | <prophet.forecaster.Prophet object at 0x000001B5C6B53350> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}       | 15296.9 |
# |  15 | <prophet.forecaster.Prophet object at 0x000001B5C64F3490> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}  | 15296.9 |
# |  16 | <prophet.forecaster.Prophet object at 0x000001B5C6F96410> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False} | 15296.9 |
# |  17 | <prophet.forecaster.Prophet object at 0x000001B5C72E9F10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}        | 15296.9 |
# |  18 | <prophet.forecaster.Prophet object at 0x000001B5C6457C10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}        | 15296.9 |
# |  19 | <prophet.forecaster.Prophet object at 0x000001B5C64B05D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}  | 15296.9 |
# |  20 | <prophet.forecaster.Prophet object at 0x000001B5C647A310> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 15326.5 |
# |  21 | <prophet.forecaster.Prophet object at 0x000001B5C7320110> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}        | 15380.7 |
# |  22 | <prophet.forecaster.Prophet object at 0x000001B5C425C5D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}  |   15421 |
# |  23 | <prophet.forecaster.Prophet object at 0x000001B5C64B4650> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 15424.9 |
# |  24 | <prophet.forecaster.Prophet object at 0x000001B5C65625D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}   | 15447.6 |
# |  25 | <prophet.forecaster.Prophet object at 0x000001B5C43BDF50> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 15454.2 |
# |  26 | <prophet.forecaster.Prophet object at 0x000001B5C6455990> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}        | 15461.1 |
# |  27 | <prophet.forecaster.Prophet object at 0x000001B5C647B790> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}   |   15463 |
# |  28 | <prophet.forecaster.Prophet object at 0x000001B5C7320D50> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}         | 15498.1 |
# |  29 | <prophet.forecaster.Prophet object at 0x000001B5C6B516D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}  | 15520.6 |
# |  30 | <prophet.forecaster.Prophet object at 0x000001B5C7365B90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}         | 15572.1 |
# |  31 | <prophet.forecaster.Prophet object at 0x000001B5C1E3E550> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 15598.2 |
# |  32 | <prophet.forecaster.Prophet object at 0x000001B5C1D6DD10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}   | 15713.4 |
# |  33 | <prophet.forecaster.Prophet object at 0x000001B5C7225790> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}   | 15973.5 |
# |  34 | <prophet.forecaster.Prophet object at 0x000001B5C6530C10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 16025.8 |
# |  35 | <prophet.forecaster.Prophet object at 0x000001B5C7188190> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 16083.9 |
# |  36 | <prophet.forecaster.Prophet object at 0x000001B5C6457D10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}  | 16551.8 |
# |  37 | <prophet.forecaster.Prophet object at 0x000001B5C7665310> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}   | 16668.5 |
# |  38 | <prophet.forecaster.Prophet object at 0x000001B5C41B8B90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}   |   16736 |
# |  39 | <prophet.forecaster.Prophet object at 0x000001B5C1DF4710> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}    | 16767.2 |
# |  40 | <prophet.forecaster.Prophet object at 0x000001B5C6455890> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 17125.3 |
# |  41 | <prophet.forecaster.Prophet object at 0x000001B5C73EB390> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}         | 17738.3 |
# |  42 | <prophet.forecaster.Prophet object at 0x000001B5C6CC8DD0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}           |   17830 |
# |  43 | <prophet.forecaster.Prophet object at 0x000001B5C6C1D350> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}          |   18289 |
# |  44 | <prophet.forecaster.Prophet object at 0x000001B5C64F3590> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 18419.9 |
# |  45 | <prophet.forecaster.Prophet object at 0x000001B5C72FF9D0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}      | 18844.3 |
# |  46 | <prophet.forecaster.Prophet object at 0x000001B5C64D89D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 19076.9 |
# |  47 | <prophet.forecaster.Prophet object at 0x000001B5C7321650> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}          |   20110 |
# |  48 | <prophet.forecaster.Prophet object at 0x000001B5C73206D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}         | 20168.1 |
# |  49 | <prophet.forecaster.Prophet object at 0x000001B5C652BF90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}           |   20293 |
# |  50 | <prophet.forecaster.Prophet object at 0x000001B5C7323C90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}        |   20317 |
# |  51 | <prophet.forecaster.Prophet object at 0x000001B5C1E3C290> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}         |   20331 |
# |  52 | <prophet.forecaster.Prophet object at 0x000001B5C1E25AD0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}          | 20631.5 |
# |  53 | <prophet.forecaster.Prophet object at 0x000001B5C6478A90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}           | 20725.6 |
# |  54 | <prophet.forecaster.Prophet object at 0x000001B5C6457290> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}         | 20807.6 |
# |  55 | <prophet.forecaster.Prophet object at 0x000001B5C64578D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}          | 20818.1 |
# |  56 | <prophet.forecaster.Prophet object at 0x000001B5C72B5510> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}         | 20852.2 |
# |  57 | <prophet.forecaster.Prophet object at 0x000001B5C647AD90> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}          |   20855 |
# |  58 | <prophet.forecaster.Prophet object at 0x000001B5C64F2310> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 20875.4 |
# |  59 | <prophet.forecaster.Prophet object at 0x000001B5C6B616D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}      | 22220.1 |
# |  60 | <prophet.forecaster.Prophet object at 0x000001B5C6500690> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 22222.6 |
# |  61 | <prophet.forecaster.Prophet object at 0x000001B5C6C2AF50> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}          | 22403.5 |
# |  62 | <prophet.forecaster.Prophet object at 0x000001B5C6496510> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}          | 24661.7 |
# |  63 | <prophet.forecaster.Prophet object at 0x000001B5C7033C50> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}      | 24770.2 |
# |  64 | <prophet.forecaster.Prophet object at 0x000001B5C64F2B10> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}           | 24778.4 |
# |  65 | <prophet.forecaster.Prophet object at 0x000001B5C64F0A50> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 25189.1 |
# |  66 | <prophet.forecaster.Prophet object at 0x000001B5C6495610> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 25257.5 |
# |  67 | <prophet.forecaster.Prophet object at 0x000001B5C759DF90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 25261.8 |
# |  68 | <prophet.forecaster.Prophet object at 0x000001B5C712DAD0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 25357.5 |
# |  69 | <prophet.forecaster.Prophet object at 0x000001B5C73B2150> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}           | 25433.2 |
# |  70 | <prophet.forecaster.Prophet object at 0x000001B5C6EC7F10> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 25513.3 |
# |  71 | <prophet.forecaster.Prophet object at 0x000001B5C64F2F10> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 25811.6 |
# |  72 | <prophet.forecaster.Prophet object at 0x000001B5C7157B90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 26052.6 |
# |  73 | <prophet.forecaster.Prophet object at 0x000001B5C6496290> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}        | 26114.1 |
# |  74 | <prophet.forecaster.Prophet object at 0x000001B5C7380D90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}  | 26114.1 |
# |  75 | <prophet.forecaster.Prophet object at 0x000001B5C73E6D50> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 26114.1 |
# |  76 | <prophet.forecaster.Prophet object at 0x000001B5C7382710> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 26114.1 |
# |  77 | <prophet.forecaster.Prophet object at 0x000001B5C7382BD0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 26114.1 |
# |  78 | <prophet.forecaster.Prophet object at 0x000001B5C7381290> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 26114.1 |
# |  79 | <prophet.forecaster.Prophet object at 0x000001B5C7380490> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}          |   26117 |
# |  80 | <prophet.forecaster.Prophet object at 0x000001B5C6494FD0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}         |   26401 |
# |  81 | <prophet.forecaster.Prophet object at 0x000001B5C7380F90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}   | 26472.7 |
# |  82 | <prophet.forecaster.Prophet object at 0x000001B5C7382A90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 26481.1 |
# |  83 | <prophet.forecaster.Prophet object at 0x000001B5C64953D0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 26635.7 |
# |  84 | <prophet.forecaster.Prophet object at 0x000001B5C6494E90> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 27039.3 |
# |  85 | <prophet.forecaster.Prophet object at 0x000001B5C7380410> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}   | 27072.3 |
# |  86 | <prophet.forecaster.Prophet object at 0x000001B5C6495950> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 27582.7 |
# |  87 | <prophet.forecaster.Prophet object at 0x000001B5C7380BD0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}    | 27751.2 |
# |  88 | <prophet.forecaster.Prophet object at 0x000001B5C423E8D0> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}    | 29636.8 |
# |  89 | <prophet.forecaster.Prophet object at 0x000001B5C6495210> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}     | 29813.1 |
# |  90 | <prophet.forecaster.Prophet object at 0x000001B5C6B60290> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 31735.7 |
# |  91 | <prophet.forecaster.Prophet object at 0x000001B5C701C2D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 31935.3 |
# |  92 | <prophet.forecaster.Prophet object at 0x000001B5C64FE6D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}          |   32217 |
# |  93 | <prophet.forecaster.Prophet object at 0x000001B5C6B61610> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}    | 32220.2 |
# |  94 | <prophet.forecaster.Prophet object at 0x000001B5C427FE90> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 32357.7 |
# |  95 | <prophet.forecaster.Prophet object at 0x000001B5C7578150> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}  | 32357.7 |
# |  96 | <prophet.forecaster.Prophet object at 0x000001B5C64DBB90> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 32357.7 |
# |  97 | <prophet.forecaster.Prophet object at 0x000001B5C885BF10> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}        | 32357.7 |
# |  98 | <prophet.forecaster.Prophet object at 0x000001B5C6500890> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 32357.7 |
# |  99 | <prophet.forecaster.Prophet object at 0x000001B5C6501C50> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 32357.7 |
# | 100 | <prophet.forecaster.Prophet object at 0x000001B5C64DA890> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}   | 32485.1 |
# | 101 | <prophet.forecaster.Prophet object at 0x000001B5C72DA950> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 32487.1 |
# | 102 | <prophet.forecaster.Prophet object at 0x000001B5C64FF550> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}         | 32527.3 |
# | 103 | <prophet.forecaster.Prophet object at 0x000001B5C6B62750> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': False}   | 32532.4 |
# | 104 | <prophet.forecaster.Prophet object at 0x000001B5C64D8710> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}    | 32582.2 |
# | 105 | <prophet.forecaster.Prophet object at 0x000001B5C6B61E10> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}     | 32683.2 |
# | 106 | <prophet.forecaster.Prophet object at 0x000001B5C6B61A90> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': False}    | 32705.7 |
# | 107 | <prophet.forecaster.Prophet object at 0x000001B5C8A340D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}          | 32758.9 |
# | 108 | <prophet.forecaster.Prophet object at 0x000001B5C6E3C210> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}           | 32827.6 |
# | 109 | <prophet.forecaster.Prophet object at 0x000001B5C6D0EB10> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': False}    | 32840.3 |
# | 110 | <prophet.forecaster.Prophet object at 0x000001B5C9093FD0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}    |   32868 |
# | 111 | <prophet.forecaster.Prophet object at 0x000001B5C64FC450> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 32913.5 |
# | 112 | <prophet.forecaster.Prophet object at 0x000001B5C87E1090> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}         | 32928.5 |
# | 113 | <prophet.forecaster.Prophet object at 0x000001B5C6503290> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}          | 32951.6 |
# | 114 | <prophet.forecaster.Prophet object at 0x000001B5C6B60310> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}           | 33009.2 |
# | 115 | <prophet.forecaster.Prophet object at 0x000001B5C7522C50> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 33023.4 |
# | 116 | <prophet.forecaster.Prophet object at 0x000001B5C64D96D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}    | 33038.8 |
# | 117 | <prophet.forecaster.Prophet object at 0x000001B5C6B62850> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': False}     | 33067.8 |
# | 118 | <prophet.forecaster.Prophet object at 0x000001B5C8748AD0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': False}   | 33110.7 |
# | 119 | <prophet.forecaster.Prophet object at 0x000001B5C6497790> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': False}     | 33400.7 |
# | 120 | <prophet.forecaster.Prophet object at 0x000001B5C72CB190> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 46138.4 |
# | 121 | <prophet.forecaster.Prophet object at 0x000001B5C887D010> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': False, 'yearly_seasonality': True}         | 46274.7 |
# | 122 | <prophet.forecaster.Prophet object at 0x000001B5C64FC3D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}           | 47100.6 |
# | 123 | <prophet.forecaster.Prophet object at 0x000001B5C64FD090> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01, 'weekly_seasonality': True, 'yearly_seasonality': True}          |   47132 |
# | 124 | <prophet.forecaster.Prophet object at 0x000001B5C64E9990> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 60298.6 |
# | 125 | <prophet.forecaster.Prophet object at 0x000001B5C7323050> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 64137.1 |
# | 126 | <prophet.forecaster.Prophet object at 0x000001B5C6454FD0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 65525.4 |
# | 127 | <prophet.forecaster.Prophet object at 0x000001B5C64F3690> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}    | 66441.9 |
# | 128 | <prophet.forecaster.Prophet object at 0x000001B5C6C3A110> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}   | 66617.4 |
# | 129 | <prophet.forecaster.Prophet object at 0x000001B5C43CF0D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}     | 66785.6 |
# | 130 | <prophet.forecaster.Prophet object at 0x000001B5C437FE10> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}    |   67240 |
# | 131 | <prophet.forecaster.Prophet object at 0x000001B5C6EC0950> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}     | 68049.1 |
# | 132 | <prophet.forecaster.Prophet object at 0x000001B5C6496D10> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}     | 68260.2 |
# | 133 | <prophet.forecaster.Prophet object at 0x000001B5C437D9D0> | {'changepoint_prior_scale': 0.01, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}   | 68379.9 |
# | 134 | <prophet.forecaster.Prophet object at 0x000001B5C6F10290> | {'changepoint_prior_scale': 0.1, 'daily_seasonality': False, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}    | 71752.2 |
# | 135 | <prophet.forecaster.Prophet object at 0x000001B5C6B61710> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}     | 73531.8 |
# | 136 | <prophet.forecaster.Prophet object at 0x000001B5C6E40A50> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}           | 93243.3 |
# | 137 | <prophet.forecaster.Prophet object at 0x000001B5C6E7D990> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': False, 'yearly_seasonality': True}          | 93370.8 |
# | 138 | <prophet.forecaster.Prophet object at 0x000001B5C6503950> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}           | 95829.4 |
# | 139 | <prophet.forecaster.Prophet object at 0x000001B5C6CE4850> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1, 'weekly_seasonality': True, 'yearly_seasonality': True}            |  102850 |
# | 140 | <prophet.forecaster.Prophet object at 0x000001B5C6B61010> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}           |  107003 |
# | 141 | <prophet.forecaster.Prophet object at 0x000001B5C8ACAE50> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': False, 'yearly_seasonality': True}          |  108484 |
# | 142 | <prophet.forecaster.Prophet object at 0x000001B5C64FE4D0> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': True, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}            |  109756 |
# | 143 | <prophet.forecaster.Prophet object at 0x000001B5C6502910> | {'changepoint_prior_scale': 1.0, 'daily_seasonality': False, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0, 'weekly_seasonality': True, 'yearly_seasonality': True}           |  111380 |
# +-----+-----------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------+
# CPU times: total: 43.5 s
# Wall time: 24.3 s

# %% [markdown]
# #### (3) 최적 모델을 통한 예측치 확인

# %%
best_model = result_df.iloc[0]['model']
best_model.make_future_dataframe(periods=len(test)+7, freq='D')
forecast = best_model.predict(future)

fig = best_model.plot(forecast, figsize=(15,5))
fig.set_dpi(200)
ax = fig.gca()
plt.show()
plt.close()
