# %%
from pandas import read_excel , pivot_table, crosstab, DataFrame, merge, concat

# %% [markdown]
# ![캡처.PNG2.PNG](attachment:캡처.PNG2.PNG)

# %%
data1 = {'ID':[25,27,30,35],
       'READ':[350,425,475,375],
       'MATH':[425,375,485,400],
       'GRADE':[7,8,8,9]
       }

df3 = DataFrame(data1)
df3
# Out:
#    ID  READ  MATH  GRADE
# 0  25   350   425      7
# 1  27   425   375      8
# 2  30   475   485      8
# 3  35   375   400      9

# %%
data2 = {'ID':[20,33,37],
       'READ':[250,325,300],
       'MATH':[300,225,375],
       'GRADE':[7,9,9]
       }

df4 = DataFrame(data2)
df4
# Out:
#    ID  READ  MATH  GRADE
# 0  20   250   300      7
# 1  33   325   225      9
# 2  37   300   375      9

# %%
df5 = concat([df3,df4], ignore_index=True)

# %%
df5.to_excel("문제2.xlsx", index=False)

# %%
from pandas import read_excel , pivot_table, crosstab, DataFrame

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
origin = read_excel("http://data.hossam.kr/pydata/smoke.xlsx")
origin
# Out:
#     지역  구성   흡연율
# 0   도시   남  0.64
# 1   도시   여  0.45
# 2   농촌  공학  0.70
# 3   도시   남  0.85
# 4   농촌   남  0.72
# 5   도시   남  0.78
# 6   도시   여  0.62
# 7   도시   남  0.79
# 8   농촌   남  0.75
# 9   농촌  공학  0.81
# 10  농촌   여  0.56
# 11  도시   여  0.48
# 12  농촌   남  0.72
# 13  도시  공학  0.68
# 14  농촌   남  0.79
# 15  도시   남  0.90
# 16  농촌   여  0.34
# 17  도시   여  0.48
# 18  농촌   여  0.49
# 19  농촌  공학  0.76

# %%
pivot_table(origin,index=['지역'],
                          columns=['구성'],
                          values='흡연율',
                          aggfunc=['mean'])
# Out:
#         mean
# 구성        공학      남         여
# 지역
# 농촌  0.756667  0.745  0.463333
# 도시  0.680000  0.792  0.507500

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %%
df = read_excel('https://data.hossam.kr/pydata/privacy.xlsx')
df
# Out:
#     학생ID 성별  메모종류
# 0      1  남     3
# 1      2  여     2
# 2      3  여     2
# 3      4  여     1
# 4      5  여     2
# 5      6  여     3
# 6      7  남     2
# 7      8  여     2
# 8      9  여     1
# 9     10  남     1
# 10    11  남     2
# 11    12  남     3
# 12    13  남     2
# 13    14  남     1
# 14    15  남     2
# 15    16  여     2
# 16    17  여     1
# 17    18  여     2
# 18    19  여     3
# 19    20  여     2
# 20    21  여     2
# 21    22  여     2
# 22    23  여     2
# 23    24  여     2
# 24    25  여     2
# 25    26  여     2
# 26    27  여     2
# 27    28  여     2
# 28    29  여     1
# 29    30  여     2

# %%
df['메모종류'].value_counts()
# Out:
# 메모종류
# 2    20
# 1     6
# 3     4
# Name: count, dtype: int64

# %%
pivot_table(df,index=['성별'],
                          columns=['메모종류'],
                          values='학생ID',
                          )
# Out:
# 메모종류      1       2     3
# 성별
# 남     12.00  11.500   6.5
# 여     14.75  18.625  12.5

# %%
crosstab(index=df['성별'],
                          columns=df['메모종류'],
                          margins=True,
                          normalize=True
                          )
# Out:
# 메모종류         1         2         3       All
# 성별
# 남     0.066667  0.133333  0.066667  0.266667
# 여     0.133333  0.533333  0.066667  0.733333
# All   0.200000  0.666667  0.133333  1.000000
