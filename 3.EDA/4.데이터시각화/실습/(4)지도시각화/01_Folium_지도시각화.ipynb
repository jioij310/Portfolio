# %% [markdown]
# # 지도 시각화
#
# ## #01. 준비작업
#
# ### [1] 패키지 참조
#
# `folium` 패키지가 설치되어 있어야 한다.

# %%
import folium
from pandas import read_excel
from os import path, mkdir

# %% [markdown]
# ## #02. 지도 표현하기
#
# ### [1] 지도 객체 생성
#
# 지도의 중심이 되는 위도와 경도를 설정

# %%
map_osm = folium.Map(location=[37.77044744, 128.922632],zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fb5764c0fe6aa58efdac6bed35e0d3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fb5764c0fe6aa58efdac6bed35e0d3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fb5764c0fe6aa58efdac6bed35e0d3c = L.map(
#                 &quot;map_4fb5764c0fe6aa58efdac6bed35e0d3c&quot;,
#                 {
#                     center: [37.77044744, 128.922632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27be53f0ffca8df381fc642256520e41 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_27be53f0ffca8df381fc642256520e41.addTo(map_4fb5764c0fe6aa58efdac6bed35e0d3c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### [2] 지도 객체에 마커 추가
#
# #### (1) 일반 마커
#
# 아이콘 색상값 종류
#
# > 'lightgreen', 'darkgreen', 'darkblue', 'cadetblue', 'orange', 'lightred', 'darkred', 'green', 'blue', 'black', 'lightblue', 'white', 'lightgray', 'red', 'pink', 'beige', 'gray', 'purple', 'darkpurple'

# %%
map_osm1 = folium.Map(location=[37.5004444, 127.0313861],zoom_start=17)

marker1 = folium.Marker([37.5004444, 127.0313861],popup='메가스터디',icon=folium.Icon(color='darkred'))
marker1.add_to(map_osm1)
map_osm1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ee94f0283b29269e1d3f1675591b3a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ee94f0283b29269e1d3f1675591b3a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ee94f0283b29269e1d3f1675591b3a8 = L.map(
#                 &quot;map_2ee94f0283b29269e1d3f1675591b3a8&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f715226f79afa7c4ffb4a15f45e20920 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f715226f79afa7c4ffb4a15f45e20920.addTo(map_2ee94f0283b29269e1d3f1675591b3a8);
#
#
#             var marker_dce8bed603cdd84f9c71a67e8d5fab6a = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_2ee94f0283b29269e1d3f1675591b3a8);
#
#
#             var icon_eb2a23992fe626a9ac51bfb5c966e190 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dce8bed603cdd84f9c71a67e8d5fab6a.setIcon(icon_eb2a23992fe626a9ac51bfb5c966e190);
#
#
#         var popup_b8c9f45d05cd5610ff44ab44579981cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46e3e604ff9e33619092d88c7ce44485 = $(`&lt;div id=&quot;html_46e3e604ff9e33619092d88c7ce44485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;메가스터디&lt;/div&gt;`)[0];
#                 popup_b8c9f45d05cd5610ff44ab44579981cd.setContent(html_46e3e604ff9e33619092d88c7ce44485);
#
#
#
#         marker_dce8bed603cdd84f9c71a67e8d5fab6a.bindPopup(popup_b8c9f45d05cd5610ff44ab44579981cd)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### (2) 사용자 지정 아이콘, HTML 팝업

# %%
map_osm2 = folium.Map(location=[37.5004444, 127.0313861],zoom_start=17)

popup_html = folium.Popup("<div style='white-space: nowrap'><h3>메가스터디IT아카데미 강남</h3><img src='https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png' width='100%'><br/><p>tel: <a href='tel:07043380972'>070-4338-0972</a></p><p>서울특별시 강남구 강남대로94길 삼경빌딩 2층</p></div>", parse_html=False)
icon_img = folium.features.CustomIcon('https://data.hossam.kr/mapdata/ho.png', icon_size=(50, 50))

marker2 = folium.Marker([37.5004444, 127.0313861],popup=popup_html,icon=icon_img)
marker2.add_to(map_osm2)

if not path.exists('output'):
    mkdir('output')

map_osm2.save('output/map_osm2.html')
map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b752a0bde1a9ab9e4297f3c77867bec9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b752a0bde1a9ab9e4297f3c77867bec9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b752a0bde1a9ab9e4297f3c77867bec9 = L.map(
#                 &quot;map_b752a0bde1a9ab9e4297f3c77867bec9&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c851c1c9ee821ac9392422d77d463ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6c851c1c9ee821ac9392422d77d463ec.addTo(map_b752a0bde1a9ab9e4297f3c77867bec9);
#
#
#             var marker_d12cb326a8e808165a8076a7aedf037d = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_b752a0bde1a9ab9e4297f3c77867bec9);
#
#
#         var custom_icon_6d56a4c2952ee50402e9ca21c95fe60a = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;https://data.hossam.kr/mapdata/ho.png&quot;});
#         marker_d12cb326a8e808165a8076a7aedf037d.setIcon(custom_icon_6d56a4c2952ee50402e9ca21c95fe60a);
#
#
#         var popup_0901987bed26f5ebccc38e4e7abab3d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d5f4e216b4f4bb0db4b1363397b935c = $(`&lt;div id=&quot;html_5d5f4e216b4f4bb0db4b1363397b935c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;white-space: nowrap&#x27;&gt;&lt;h3&gt;메가스터디IT아카데미 강남&lt;/h3&gt;&lt;img src=&#x27;https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png&#x27; width=&#x27;100%&#x27;&gt;&lt;br/&gt;&lt;p&gt;tel: &lt;a href=&#x27;tel:07043380972&#x27;&gt;070-4338-0972&lt;/a&gt;&lt;/p&gt;&lt;p&gt;서울특별시 강남구 강남대로94길 삼경빌딩 2층&lt;/p&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_0901987bed26f5ebccc38e4e7abab3d4.setContent(html_5d5f4e216b4f4bb0db4b1363397b935c);
#
#
#
#         marker_d12cb326a8e808165a8076a7aedf037d.bindPopup(popup_0901987bed26f5ebccc38e4e7abab3d4)
#         ;
#
#
#
#
#             tile_layer_6c851c1c9ee821ac9392422d77d463ec.addTo(map_b752a0bde1a9ab9e4297f3c77867bec9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# (3) 원형 마커(범위지정)

# %%
map_osm3 = folium.Map(location=[37.5004444, 127.0313861],zoom_start=17)

marker1 = folium.Marker([37.5004444, 127.0313861],icon=folium.Icon(color='orange'))

marker2 = folium.CircleMarker([37.5004444, 127.0313861],radius=100, color='#3186cc',fill_color='#3186cc')

marker2.add_to(map_osm3)
marker1.add_to(map_osm3)

map_osm3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a03134d9e8ff0a046325b599217f406d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a03134d9e8ff0a046325b599217f406d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a03134d9e8ff0a046325b599217f406d = L.map(
#                 &quot;map_a03134d9e8ff0a046325b599217f406d&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af88875e5b507bf30d77061645e518b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_af88875e5b507bf30d77061645e518b7.addTo(map_a03134d9e8ff0a046325b599217f406d);
#
#
#             var circle_marker_0d9fc7a1649ab80095328c6a963695d7 = L.circleMarker(
#                 [37.5004444, 127.0313861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a03134d9e8ff0a046325b599217f406d);
#
#
#             var marker_ebc71df222248c5f181881653cc0e28c = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_a03134d9e8ff0a046325b599217f406d);
#
#
#             var icon_8b4b03ab30735c7b07094080d21cf961 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ebc71df222248c5f181881653cc0e28c.setIcon(icon_8b4b03ab30735c7b07094080d21cf961);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## #03. (예제) 서울의 고등학교 분포 확인하기
#
# ### [1] 데이터 준비하기
#
# 전국 초,중,고 학교 위치 엑셀 파일을 원격으로 내려받아 데이터프레임으로 변환 (다소 시간이 소요된다.)
#
# > 공공데이터 포털

# %%
origin = read_excel('https://data.hossam.kr/mapdata/school.xlsx')
origin
# Out:
#              학교ID          학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0      B000004204       한울초등학교  초등학교  2008-09-01   공립     본교   운영
# 1      B000011476  수원농생명과학고등학교  고등학교  1936-07-01   공립     본교   운영
# 2      B000009647        녹양중학교   중학교  2008-03-01   공립     본교   운영
# 3      B000005955       초락초등학교  초등학교  1959-04-02   공립     본교   운영
# 4      B000005385       상봉초등학교  초등학교  1946-09-01   공립     본교   운영
# ...           ...          ...   ...         ...  ...    ...  ...
# 11983  B000003371     대전옥계초등학교  초등학교  1982-12-09   공립     본교   운영
# 11984  B000003345       성덕초등학교  초등학교  2011-03-11   공립     본교   운영
# 11985  B000005441       이월초등학교  초등학교  1920-04-01   공립     본교   운영
# 11986  B000009875        해안중학교   중학교  1979-03-08   공립     본교   운영
# 11987  B000011237        초계중학교   중학교  1952-06-01   공립     본교   운영
#
#                           소재지지번주소                                    소재지도로명주소  \
# 0             경기도 화성시 향남읍 행정리 442        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1             경기도 수원시 장안구 영화동 109         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2              경기도 의정부시 녹양동 191-5              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3         충청남도 당진시 석문면 초락도리 210-3                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4      충청북도 청주시 흥덕구 오송읍 상봉리 242-1       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...                           ...                                         ...
# 11983             대전광역시 중구 옥계동 65             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984          광주광역시 광산구 장덕동 1042            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985        충청북도 진천군 이월면 송림리 667         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986          강원도 양구군 해안면 현리 143                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987         경상남도 합천군 초계면 아막리 99  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#        시도교육청코드    시도교육청명  교육지원청코드        교육지원청명        생성일자        변경일자  \
# 0      7530000    경기도교육청  7679000  경기도화성오산교육지원청  2013-11-29  2022-10-06
# 1      7530000    경기도교육청  7541000    경기도수원교육지원청  2013-11-29  2022-10-06
# 2      7530000    경기도교육청  7561000   경기도의정부교육지원청  2013-11-29  2022-10-06
# 3      8140000   충청남도교육청  8291000   충청남도당진교육지원청  2013-11-29  2022-10-06
# 4      8000000   충청북도교육청  8011000   충청북도청주교육지원청  2013-11-29  2022-10-06
# ...        ...       ...      ...           ...         ...         ...
# 11983  7430000  대전광역시교육청  7441000  대전광역시동부교육지원청  2013-11-29  2022-10-06
# 11984  7380000  광주광역시교육청  7401000  광주광역시서부교육지원청  2013-11-29  2022-10-06
# 11985  8000000   충청북도교육청  8081000   충청북도진천교육지원청  2013-11-29  2022-10-06
# 11986  7800000    강원도교육청  7951000    강원도양구교육지원청  2013-11-29  2022-10-06
# 11987  9010000   경상남도교육청  9221000   경상남도합천교육지원청  2013-11-29  2022-10-06
#
#               위도          경도     데이터기준일자   제공기관코드            제공기관명
# 0      37.126961  126.917854  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 1      37.295154  127.019450  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 2      37.761864  127.028084  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 3      36.993080  126.510472  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 4      36.638251  127.286142  2023-03-22  C738100  청주대학교 지방교육재정연구원
# ...          ...         ...         ...      ...              ...
# 11983  36.301199  127.449039  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11984  35.199148  126.814301  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11985  36.931076  127.431922  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11986  38.283771  128.135686  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11987  35.560066  128.270502  2023-03-22  C738100  청주대학교 지방교육재정연구원
#
# [11988 rows x 20 columns]

# %% [markdown]
# ### [2] 데이터 전처리
#
# #### (1) 사용할 필드만 추출

# %%
df = origin[['학교명','학교급구분','소재지도로명주소','위도','경도']]
df
# Out:
#                학교명 학교급구분                                    소재지도로명주소  \
# 0           한울초등학교  초등학교        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1      수원농생명과학고등학교  고등학교         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2            녹양중학교   중학교              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3           초락초등학교  초등학교                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4           상봉초등학교  초등학교       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...            ...   ...                                         ...
# 11983     대전옥계초등학교  초등학교             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984       성덕초등학교  초등학교            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985       이월초등학교  초등학교         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986        해안중학교   중학교                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987        초계중학교   중학교  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#               위도          경도
# 0      37.126961  126.917854
# 1      37.295154  127.019450
# 2      37.761864  127.028084
# 3      36.993080  126.510472
# 4      36.638251  127.286142
# ...          ...         ...
# 11983  36.301199  127.449039
# 11984  35.199148  126.814301
# 11985  36.931076  127.431922
# 11986  38.283771  128.135686
# 11987  35.560066  128.270502
#
# [11988 rows x 5 columns]

# %% [markdown]
# #### 서울시의 고등학교만 추출
#
# 학교급구분 필드 값이 고등학교이고, 소재지도로명주소에 `서울` 이라는 단어가 포함된 경우
#
# ```python
# # LIKE 연산
#  컬럼이름.str.contains('검색어')
# ```

# %%
df2 = df.query("학교급구분 == '고등학교' and 소재지도로명주소.str.contains('서울')")
df2
# Out:
#               학교명 학교급구분                                        소재지도로명주소  \
# 6          경기고등학교  고등학교               서울특별시 강남구 영동대로 643 . 경기고등학교 (삼성동)
# 89       대일관광고등학교  고등학교  서울특별시 양천구 신정이펜1로 11 . 대일관광고등학교 (신정동. 대일관광고등학교)
# 97         한광고등학교  고등학교                      서울특별시 강서구 등촌로13길 110 (화곡동)
# 98      상일미디어고등학교  고등학교         서울특별시 강동구 천호대로219길 61 . 상일미디어고등학교 (상일동)
# 118    선정국제관광고등학교  고등학교         서울특별시 은평구 서오릉로20길 19 . 선정국제관광고등학교 (갈현동)
# ...           ...   ...                                             ...
# 11429      성수고등학교  고등학교              서울특별시 성동구 서울숲길 18 . 성수고등학교 (성수동1가)
# 11451    대진여자고등학교  고등학교              서울특별시 노원구 공릉로 438 . 대진여자고등학교 (중계동)
# 11564      도선고등학교  고등학교                       서울특별시 성동구 마장로 156 (하왕십리동)
# 11600      금호고등학교  고등학교               서울특별시 성동구 금호로 118 (금호동1가. 금호고등학교)
# 11929  서울인공지능고등학교  고등학교                          서울특별시 송파구 양산로 21 (거여동)
#
#               위도          경도
# 6      37.517565  127.056076
# 89     37.511414  126.834907
# 97     37.538844  126.857922
# 98     37.549470  127.170767
# 118    37.618705  126.909032
# ...          ...         ...
# 11429  37.547342  127.038253
# 11451  37.646174  127.067197
# 11564  37.566844  127.026996
# 11600  37.553621  127.023434
# 11929  37.491753  127.142331
#
# [320 rows x 5 columns]

# %% [markdown]
# ### 3) 데이터 시각화

# %%
map_osm = folium.Map(location=[37.566651,126.978428],zoom_start=17)
html = "<font color='green' style='white-space: nowrap'><b>%s</b></font>"

for i in df2.index:
    name = df2.loc[i, '학교명']
    lat = df2.loc[i, '위도']
    lng = df2.loc[i, '경도']

    popup_html = folium.Popup(html % name, parse_html=False)
    marker = folium.Marker([lat,lng], popup=popup_html)
    marker.add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3a24b6aad39642774eed3aa4362f7d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3a24b6aad39642774eed3aa4362f7d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3a24b6aad39642774eed3aa4362f7d2 = L.map(
#                 &quot;map_e3a24b6aad39642774eed3aa4362f7d2&quot;,
#                 {
#                     center: [37.566651, 126.978428],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_523dc2bb73978e643662dd4053c30f51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_523dc2bb73978e643662dd4053c30f51.addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#             var marker_a4f9db6cd102c1349778e21bcc6f7f79 = L.marker(
#                 [37.5175645399, 127.0560755056],
#                 {}
#             ).addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#         var popup_2f1af8c2f4e915f301854df0be48ea3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9f3a18e30a3faedf7a4f15238af3915 = $(`&lt;div id=&quot;html_c9f3a18e30a3faedf7a4f15238af3915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;경기고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_2f1af8c2f4e915f301854df0be48ea3a.setContent(html_c9f3a18e30a3faedf7a4f15238af3915);
#
#
#
#         marker_a4f9db6cd102c1349778e21bcc6f7f79.bindPopup(popup_2f1af8c2f4e915f301854df0be48ea3a)
#         ;
#
#
#
#
#             var marker_e44d8ad32cea983bbef3e498d2482ec8 = L.marker(
#                 [37.5114137684, 126.8349067147],
#                 {}
#             ).addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#         var popup_4829adeefe60ef6f16487402cd5d50a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_880d3f65deaae29591c978ac68024ec2 = $(`&lt;div id=&quot;html_880d3f65deaae29591c978ac68024ec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;대일관광고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_4829adeefe60ef6f16487402cd5d50a2.setContent(html_880d3f65deaae29591c978ac68024ec2);
#
#
#
#         marker_e44d8ad32cea983bbef3e498d2482ec8.bindPopup(popup_4829adeefe60ef6f16487402cd5d50a2)
#         ;
#
#
#
#
#             var marker_e4ab1e2d49723a6d212a9bae4d444f63 = L.marker(
#                 [37.5388437129, 126.857922],
#                 {}
#             ).addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#         var popup_08862fb2bfea1086d602a80c89dcaaf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adb08e9cd02f887a628b6f39f9a55102 = $(`&lt;div id=&quot;html_adb08e9cd02f887a628b6f39f9a55102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;한광고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_08862fb2bfea1086d602a80c89dcaaf9.setContent(html_adb08e9cd02f887a628b6f39f9a55102);
#
#
#
#         marker_e4ab1e2d49723a6d212a9bae4d444f63.bindPopup(popup_08862fb2bfea1086d602a80c89dcaaf9)
#         ;
#
#
#
#
#             var marker_f9c1de32deed5cca86ca5d2294dbf1fb = L.marker(
#                 [37.5494699071, 127.1707668179],
#                 {}
#             ).addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#         var popup_684d70bfa9dd9d0e58fee92e15b6b418 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2c6dee893a88fdaa8316cc1f22cf34b = $(`&lt;div id=&quot;html_b2c6dee893a88fdaa8316cc1f22cf34b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;상일미디어고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_684d70bfa9dd9d0e58fee92e15b6b418.setContent(html_b2c6dee893a88fdaa8316cc1f22cf34b);
#
#
#
#         marker_f9c1de32deed5cca86ca5d2294dbf1fb.bindPopup(popup_684d70bfa9dd9d0e58fee92e15b6b418)
#         ;
#
#
#
#
#             var marker_f4583783afb178f37218ee2b3904ec1a = L.marker(
#                 [37.6187045126, 126.9090316117],
#                 {}
#             ).addTo(map_e3a24b6aad39642774eed3aa4362f7d2);
#
#
#         var popup_1f2f162a8f4fff948d9e91d941357fc7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccf2c7ce927a6e4f9305dcb144428236 = $(`&lt;div id=&quot;html_ccf2c7ce927a6e4f9305dcb144428236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style

# %% [markdown]
# map = folium.Map([37.123,126.])
# map
