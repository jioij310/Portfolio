# %%
import requests
import json
import datetime as dt

# %%
urlFmt = "https://dapi.kakao.com/v3/search/book?query={query}&page={page}&size={size}"

# %%
query = "python"
page = 1
size = 50
key = ""

# %%
session = requests.Session()

session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Authorization": "KakaoAK %s" % key
})

# %%
url = urlFmt.format(query=query, page=page, size=size)

try:
    r = session.get(url)

    if r.status_code !=200:
        msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
        raise Exception(msg)

except Exception as e:
    print("접속에 실패했습니다.")
    print(e)

# %%
r.encoding = "utf-8"
mydict = json.loads(r.text)
print(type(mydict))
mydict
# Out:
# <class 'dict'>
# {'documents': [{'authors': ['박응용'],
#    'contents': '개정 2판으로 새롭게 태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 설명과 예제를 다듬고, 최신 경향과 심화 내용을 보충했다. 또한 이번 개정 2판도 50만 코딩 유튜버인 조코딩과 협업을 통해 유튜브 동영상을 제공해 파이썬을 더 쉽게 공부할 수 있다.  8년 연속 베스트셀러! 위키독스 누적 방문 300만! 독자의 입에서 입으로 전해진 추천과 수많은 대학 및 학원의 교재 채택을 통해 검증은 이미 끝났다. 코딩을 처음 배우는 중고등학생부터 코딩',
#    'datetime': '2023-06-15T00:00:00.000+09:00',
#    'isbn': '1163034738 9791163034735',
#    'price': 22000,
#    'publisher': '이지스퍼블리싱',
#    'sale_price': 19800,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6361131%3Ftimestamp%3D20231205154634',
#    'title': 'Do it! 점프 투 파이썬',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6361131&q=Do+it%21+%EC%A0%90%ED%94%84+%ED%88%AC+%ED%8C%8C%EC%9D%B4%EC%8D%AC'},
#   {'authors': ['윤인성'],
#    'contents': '『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별 학습은 그대로! 혼자 공부하더라도 체계적으로 계획을 세워 학습할 수 있도록 ‘혼공 계획표’를 새롭게 추가했습니다. 또한 입문자가 자주 물어보는 질문과 오류 해결 방법을 적재적소에 배치하여 예상치 못한 문제에 부딪혀도 좌절하지 않고 끝까지 완독할 수 있도록 도와줍니다. 단순한 문법 암기와 코딩 따라하기에 지쳤다면, 새로운',
#    'datetime': '2022-06-01T00:00:00.000+09:00',
#    'isbn': '1162245654 9791162245651',
#    'price': 22000,
#    'publisher': '한빛미디어',
#    'sale_price': 19800,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6080832%3Ftimestamp%3D20231124174616',
#    'title': '혼자 공부하는 파이썬',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6080832&q=%ED%98%BC%EC%9E%90+%EA%B3%B5%EB%B6%80%ED%95%98%EB%8A%94+%ED%8C%8C%EC%9D%B4%EC%8D%AC'},
#   {'authors': ['박응용'],
#    'contents': '문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개정판으로 새로 태어났다! 2016년 《Do it! 점프 투 파이썬》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다. 특히 ‘나 혼자 코딩’과 ‘코딩 면허 시험 20제’ 등 독자의 학습 흐름에 맞게 문제를 보강한 점이 눈에 띈다. 실습량도 두 배로 늘었다.  4년 동안 압도적 1위! 위키독스',
#    'datetime': '2019-06-20T00:00:00.000+09:00',
#    'isbn': '1163030910 9791163030911',
#    'price': 18800,
#    'publisher': '이지스퍼블리싱',
#    'sale_price': 16920,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F4977247%3Ftimestamp%3D20231210151929',
#    'title': 'Do it! 점프 투 파이썬',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4977247&q=Do+it%21+%EC%A0%90%ED%94%84+%ED%88%AC+%ED%8C%8C%EC%9D%B4%EC%8D%AC'},
#   {'authors': ['Packt Publishing'],
#    'contents': '',
#    'datetime': '2017-01-31T00:00:00.000+09:00',
#    'isbn': '1787125181 9781787125186',
#    'price': 110230,
#    'publisher': 'Packt Publishing',
#    'sale_price': 102790,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3639774%3Ftimestamp%3D20230918171817',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3639774&q=Python'},
#   {'authors': ['나도코딩'],
#    'contents': '유튜브와 인프런 최고의 인기 강의를 한 권에 담았습니다. 일상 속 재미있는 예제로 파이썬 기본 개념을 배우고 1분 퀴즈, 실습 문제, 셀프체크로 이어지는 단계별 학습으로 파이썬을 완공할 수 있습니다. 이제 코딩은 선택이 아닌 필수! 코딩은 전공자만 배울 수 있다는 생각으로 지레 포기하지 마세요. 파이썬은 초보자가 가장 쉽게 배울 수 있는 프로그래밍 언어입니다. 관심만 있다면 누구나 코딩을 배울 수 있습니다. 나도코딩이 쉽고 재미있게 알려드립니다. 코딩',
#    'datetime': '2023-02-20T00:00:00.000+09:00',
#    'isbn': '1140703307 9791140703302',
#    'price': 24000,
#    'publisher': '길벗',
#    'sale_price': 21600,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6282674%3Ftimestamp%3D20230905155527',
#    'title': '코딩 자율학습 나도코딩의 파이썬 입문',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6282674&q=%EC%BD%94%EB%94%A9+%EC%9E%90%EC%9C%A8%ED%95%99%EC%8A%B5+%EB%82%98%EB%8F%84%EC%BD%94%EB%94%A9%EC%9D%98+%ED%8C%8C%EC%9D%B4%EC%8D%AC+%EC%9E%85%EB%AC%B8'},
#   {'authors': ['김충석'],
#    'contents': '『컴퓨팅 사고력 프로그래밍 PYTHON』은 프로그램과 코딩을 처음 배우는 학습자를 위한 책으로 컴퓨팅 사고력에 기반한 문제해결 기법을 다루며 컴퓨팅 사고력에 기반한 문제를 파이썬으로 해결을 돕고 프로그램의 논리와 파이썬의 구조를 쉽게 설명하며 컴퓨팅 사고력 프로젝트를 통하여 개발 경험을 얻을 수 있는 책이다.',
#    'datetime': '2020-02-10T00:00:00.000+09:00',
#    'isbn': '8993163626 9788993163629',
#    'price': 22000,
#    'publisher': '이한미디어',
#    'sale_price': 22000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5241408%3Ftimestamp%3D20220930220047',
#    'title': '컴퓨팅 사고력 프로그래밍 PYTHON',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5241408&q=%EC%BB%B4%ED%93%A8%ED%8C%85+%EC%82%AC%EA%B3%A0%EB%A0%A5+%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D+PYTHON'},
#   {'authors': ['이진영'],
#    'contents': '가운데 프로그래밍 언어를 이용하여 프로그래밍 개념을 정립하고 이를 바탕으로 문제해결 방법을 학습하는 소프트웨어 개발을 위한 코딩 교육이 부각되고 있다. 최근에는 전공자뿐만 아니라 비전공자에게 직관적이고 간결하며 이해하기 쉬운 Python이 프로그래밍 학습을 위한 언어로 주목을 받고 있다. 따라서 이 책에서는 독자가 컴퓨팅 사고를 학습하는 데 도움이 되는 Python을 보다 쉽게 이해하고 학습할 수 있도록 다양한 예제와 도식을 이용하여 설명하고 있다.  초급학습자',
#    'datetime': '2017-08-25T00:00:00.000+09:00',
#    'isbn': '8994044965 9788994044965',
#    'price': 21000,
#    'publisher': '서현사',
#    'sale_price': 21000,
#    'status': '예약판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F1414183%3Ftimestamp%3D20220410084643',
#    'title': 'Python 실습으로 기초부터',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=1414183&q=Python+%EC%8B%A4%EC%8A%B5%EC%9C%BC%EB%A1%9C+%EA%B8%B0%EC%B4%88%EB%B6%80%ED%84%B0'},
#   {'authors': ['최예신', '박진원', '이경숙', '김주현'],
#    'contents': '1. 빅데이터분석기사 실기시험 합격을 위한 최고의 대비서 현업 데이터사이언티스트의 모든 노하우를 담아낸 완벽 대비서  2. 최신기출복원문제 총 4회분 수록 필답형은 물론 작업형 모범 답안 코드까지 모두 수록  3. 핵심 이론+챕터별 마무리 문제로 효율적인 실전 대비 빈출 핵심 이론 학습 후 마무리 문제로 가장 효율적인 학습  4. 파이썬 입문자도 데이터분석가로 만들어주는 파이썬 A to Z 기본 문법부터 라이브러리 활용까지, 최적의 데이터분석 입문서',
#    'datetime': '2023-05-15T00:00:00.000+09:00',
#    'isbn': '1163861618 9791163861614',
#    'price': 30000,
#    'publisher': '예문에듀',
#    'sale_price': 27000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6292671%3Ftimestamp%3D20231210153526',
#    'title': '2023 빅데이터분석기사 실기 한권완성 필답형+작업형[파이썬(Python)]',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6292671&q=2023+%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B8%B0%EC%82%AC+%EC%8B%A4%EA%B8%B0+%ED%95%9C%EA%B6%8C%EC%99%84%EC%84%B1+%ED%95%84%EB%8B%B5%ED%98%95%2B%EC%9E%91%EC%97%85%ED%98%95%5B%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29%5D'},
#   {'authors': ['프랑소와 숄레'],
#    'contents': '케라스 창시자이자 구글 딥러닝 연구원인 저자는 ‘인공 지능의 민주화’를 강조한다. 이 책 역시 많은 사람에게 딥러닝을 전달하는 또 다른 방법이며, 딥러닝 이면의 개념과 구현을 가능하면 쉽게 이해할 수 있게 하는 데 중점을 두었다. 1부에서는 딥러닝, 신경망, 머신 러닝의 기초를, 2부에서는 컴퓨터 비전, 텍스트, 시퀀스, 생성 모델을 위한 딥러닝 같은 실전 딥러닝을 설명한다. 이외에도 딥러닝을 언제 적용하는지, 한계는 무엇인지, 저자가 생각하는',
#    'datetime': '2018-10-22T00:00:00.000+09:00',
#    'isbn': '1160505977 9791160505979',
#    'price': 33000,
#    'publisher': '길벗',
#    'sale_price': 29700,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3774757%3Ftimestamp%3D20220901164716',
#    'title': '케라스 창시자에게 배우는 딥러닝(Deep Learning with Python)',
#    'translators': ['박해선'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3774757&q=%EC%BC%80%EB%9D%BC%EC%8A%A4+%EC%B0%BD%EC%8B%9C%EC%9E%90%EC%97%90%EA%B2%8C+%EB%B0%B0%EC%9A%B0%EB%8A%94+%EB%94%A5%EB%9F%AC%EB%8B%9D%28Deep+Learning+with+Python%29'},
#   {'authors': ['모리 요시나오'],
#    'contents': '인공지능의 인기로 학습 필요성이 높아진 머신러닝 입문서 『파이썬 3학년』이 출간되었다. 염소 박사와 다솜 양 같은 동물 캐릭터의 친근한 일러스트와 묻고 답하는 대화형 설명으로 친숙한 『파이썬 1학년』이 출간된 이후 『파이썬 2학년 스크래핑의 구조』, 『파이썬 2학년 데이터 분석 구조』이 니왔고 이번에 『파이썬 3학년 머신러닝의 구조』 편이 나온 것이다.   인공지능 머신러닝을 실습해볼 수 있는 데이터세트는 이미 많이 공개되어 있다. 이 책의 장점은',
#    'datetime': '2023-09-20T00:00:00.000+09:00',
#    'isbn': '8931559232 9788931559231',
#    'price': 18000,
#    'publisher': '성안당',
#    'sale_price': 16200,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6439736%3Ftimestamp%3D20231027180739',
#    'title': '파이썬(Python) 3학년 머신러닝의 구조',
#    'translators': ['김성훈'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6439736&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29+3%ED%95%99%EB%85%84+%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EC%9D%98+%EA%B5%AC%EC%A1%B0'},
#   {'authors': ['최예신', '박진원', '이경숙', '김주현'],
#    'contents': '1. 빅데이터분석기사 실기시험 합격을 위한 최고의 대비서 현업 데이터사이언티스트의 모든 노하우를 담아낸 완벽 대비서 2. 시험 유형 변경 대비, 제3유형 히든카드 수록 핵심 이론 + 연습 문제 + 마무리 문제로 제3유형 완벽 대비! 3. 최신기출복원문제 총 4회분 수록 필답형은 물론 작업형 모범 답안 코드까지 모두 수록 4. 파이썬 입문자도 데이터분석가로 만들어주는 파이썬 A to Z 기본 문법부터 라이브러리 활용까지, 최적의 데이터분석 입문서',
#    'datetime': '2023-06-15T00:00:00.000+09:00',
#    'isbn': '1163861995 9791163861997',
#    'price': 30000,
#    'publisher': '예문에듀',
#    'sale_price': 27000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6348281%3Ftimestamp%3D20231108160636',
#    'title': '2023 빅데이터분석기사 실기 한권완성 파이썬(Python)',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6348281&q=2023+%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B8%B0%EC%82%AC+%EC%8B%A4%EA%B8%B0+%ED%95%9C%EA%B6%8C%EC%99%84%EC%84%B1+%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29'},
#   {'authors': ['장삼용'],
#    'contents': '본서는 200개의 예제로 파이썬을 마스터할 수 있도록 구성되었다. 기초적인 개념에 대해 배우는 1파트 ‘Python 프로그래밍 첫발 내딛기’를 시작으로 5파트 ‘Python으로 간단한 프로그램 작성하기’까지 다양한 예제로 실무 능력을 키울 수 있다.',
#    'datetime': '2017-02-27T00:00:00.000+09:00',
#    'isbn': '8956747342 9788956747347',
#    'price': 20000,
#    'publisher': '정보문화사',
#    'sale_price': 18000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F741949%3Ftimestamp%3D20230419175648',
#    'title': '초보자를 위한 파이썬(Python) 200제',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=741949&q=%EC%B4%88%EB%B3%B4%EC%9E%90%EB%A5%BC+%EC%9C%84%ED%95%9C+%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29+200%EC%A0%9C'},
#   {'authors': ['McGrath Mike'],
#    'contents': '',
#    'datetime': '2018-08-28T00:00:00.000+09:00',
#    'isbn': '1840788127 9781840788129',
#    'price': 17750,
#    'publisher': 'In Easy Steps',
#    'sale_price': 17610,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F4867916%3Ftimestamp%3D20230406144114',
#    'title': 'Python in Easy Steps',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4867916&q=Python+in+Easy+Steps'},
#   {'authors': ['나홍석', '배원성', '이건길', '이혜영', '고려사이버대학교 AI·빅데이터 연구소'],
#    'contents': '본 도서는 최신 출제기준을 적용한 도서로, 빅데이터분석기사 실기 시험의 출제 경향을 철저히 분석하여 수험생들이 혼자서도 학습할 수 있도록 한 완벽 대비서이다. 파이썬과 R 언어를 모두 다루며 수험자의 공부 폭을 넓혀 다양한 경험을 제공하고, 꼼꼼한 이론과 예상문제를 통해 시험 유형에 철저하게 대비할 수 있도록 하였다. 또한 실기 시험의 핵심을 다루는 모의고사 풀이 동영상을 독자에게 무료로 제공하여 시험 준비에 도움이 되도록 하였다.',
#    'datetime': '2022-05-06T00:00:00.000+09:00',
#    'isbn': '8931464797 9788931464795',
#    'price': 32000,
#    'publisher': '영진닷컴',
#    'sale_price': 28800,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6060978%3Ftimestamp%3D20231123183820',
#    'title': '이기적 빅데이터분석기사 실기 기본서',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6060978&q=%EC%9D%B4%EA%B8%B0%EC%A0%81+%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B8%B0%EC%82%AC+%EC%8B%A4%EA%B8%B0+%EA%B8%B0%EB%B3%B8%EC%84%9C'},
#   {'authors': ['임일'],
#    'contents': '현재 추천 알고리즘으로 가장 널리 사용되는 협업 필터링(Collaborative Filtering: CF),  행렬 요인화(Matrix Factorization: MF), 딥러닝(Deep Learning: DL) 알고리즘의 작동원리와 Python을 사용한 개인화 추천 시스템 구축을 다루고 있다.  추천 시스템의 기본적인 원리를 이해하는 데 활용할 수 있다.',
#    'datetime': '2020-08-25T00:00:00.000+09:00',
#    'isbn': '8959727660 9788959727667',
#    'price': 18000,
#    'publisher': '청람',
#    'sale_price': 18000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5456169%3Ftimestamp%3D20230201173519',
#    'title': 'Python을 이용한 개인화 추천시스템',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5456169&q=Python%EC%9D%84+%EC%9D%B4%EC%9A%A9%ED%95%9C+%EA%B0%9C%EC%9D%B8%ED%99%94+%EC%B6%94%EC%B2%9C%EC%8B%9C%EC%8A%A4%ED%85%9C'},
#   {'authors': ['모리 요시나오'],
#    'contents': '만화처럼 빨려 들어가는 비주얼한 프로그래밍 입문서 1학년 시리즈!  염소 박사님, 다솜 양과 함께라면 인공지능 앱도 뚝딱!    누구에게나 가볍고 쉬운 파이썬 입문서!',
#    'datetime': '2018-12-18T00:00:00.000+09:00',
#    'isbn': '8931555687 9788931555684',
#    'price': 17000,
#    'publisher': '성안당',
#    'sale_price': 15300,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F4836717%3Ftimestamp%3D20230928165247',
#    'title': '파이썬(Python): 1학년',
#    'translators': ['이영란'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4836717&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29%3A+1%ED%95%99%EB%85%84'},
#   {'authors': ['Matthes Eric'],
#    'contents': "Python Crash Course is a fast-paced, thorough introduction to programming with Python that will have you writing programs, solving problems, and making things that work in no time.    In the first half of the book, you'll learn about basic programming concepts",
#    'datetime': '2015-12-31T00:00:00.000+09:00',
#    'isbn': '1593276036 9781593276034',
#    'price': 50000,
#    'publisher': 'No Starch Press',
#    'sale_price': 47160,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3380791%3Ftimestamp%3D20230719172339',
#    'title': 'Python Crash Course',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3380791&q=Python+Crash+Course'},
#   {'authors': ['웨스 맥키니'],
#    'contents': '『파이썬 라이브러리를 활용한 데이터 분석』은 NumPy, pandas, matplotlib, IPython 등의 다양한 파이썬 라이브러리를 사용해서 효과적으로 데이터를 분석할 수 있게 알려준 책이다. 연대별 이름 통계 자료, 미 대선 데이터베이스 자료를 기반으로 한 실제 사례 연구를 따라하다 보면 어느덧 데이터에 알맞게 접근하고 효과적으로 분석할 수 있게 된다.',
#    'datetime': '2013-10-01T00:00:00.000+09:00',
#    'isbn': '8968480478 9788968480478',
#    'price': 33000,
#    'publisher': '한빛미디어',
#    'sale_price': 29700,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F944468%3Ftimestamp%3D20220129190727',
#    'title': '파이썬 라이브러리를 활용한 데이터 분석(수정개정판)',
#    'translators': ['김영근'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=944468&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC+%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EB%A5%BC+%ED%99%9C%EC%9A%A9%ED%95%9C+%EB%8D%B0%EC%9D%B4%ED%84%B0+%EB%B6%84%EC%84%9D%28%EC%88%98%EC%A0%95%EA%B0%9C%EC%A0%95%ED%8C%90%29'},
#   {'authors': ['서성채'],
#    'contents': '파이썬Python 언어는 사회 변화의 중심에서 컴퓨터를 제어하고 정보를 생성하는 역할을 하며, 초보자도 쉽게 소프트웨어를 개발할 수 있다. 저자는 대학에서 컴퓨터 프로그래밍을 강의하면서 소프트웨어 개발이 단순 프로그램 문법을 공부하는 것보다 문제를 분석하고 설계한 후 이를 언어로 구현하는 과정이 매우 중요하다는 것을 인식하였다. 이 책은 소프트웨어 프로그램 언어인 파이썬 언어의 중요성을 배우고, 인공지능 시대에 필수적인 문제 해결력분해, 추상화, 패턴',
#    'datetime': '2023-02-24T00:00:00.000+09:00',
#    'isbn': ' 9788968499579',
#    'price': 15000,
#    'publisher': '전남대학교출판문화원',
#    'sale_price': -1,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F6298875',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=6298875&q=Python'},
#   {'authors': ['박병기'],
#    'contents': '『다양한 예제로 배우는 완전 쉬운 파이썬(Python)』은 파이썬을 처음 접하는 사람이 기초를 쉽게 익히고 실무에 응용할 수 있도록 핵심 개념별로 126개의 독립된 항목으로 나누어 각 항목에 최적화된 예제를 풀어보면서 배울 수 있도록 구성했다. 특히, 필자의 현장 교육 경험을 바탕삼아 1:1 개인 지도하듯이 편안한 구어체를 이용하여 지루하지 않게 파이썬을 공부할 수 있도록 배려했다. 또한, 기능을 모두 배운 후 다양한 재미있는 프로그램을 만들어보면서 종합',
#    'datetime': '2017-01-30T00:00:00.000+09:00',
#    'isbn': '8998955954 9788998955953',
#    'price': 23000,
#    'publisher': '아티오',
#    'sale_price': 20700,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F1502532%3Ftimestamp%3D20230411195253',
#    'title': '파이썬(Python)',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=1502532&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29'},
#   {'authors': ['폴 배리'],
#    'contents': '고유한 기법으로 파이썬 언어를 가르치는 실용 안내서 『헤드 퍼스트 파이썬』. 파이썬에서 제공하는 함수 모듈, 데이터 마이닝, 데이터 랭글링 등의 기법을 다양한 예제를 통해 쉽고 빠르게 익히도록 도와준다. 파이썬의 기초를 간단히 살펴보고 영속성, 예외 처리, 웹 개발, SQLite, 데이터 마이닝, 구글 앱 엔진을 적용한다. 또한 안드로이드용 웹앱도 만들어 본다. 파이썬 프로그래머가 되기 위해 경험해야 할 모든 것을 가르쳐주는 책이다.',
#    'datetime': '2011-10-28T00:00:00.000+09:00',
#    'isbn': '8979148682 9788979148688',
#    'price': 30000,
#    'publisher': '한빛미디어',
#    'sale_price': -1,
#    'status': '',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F1103436%3Ftimestamp%3D20221025125523',
#    'title': 'Python(Head First)',
#    'translators': ['강권학'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=1103436&q=Python%28Head+First%29'},
#   {'authors': ['알 스웨이가트'],
#    'contents': "your computer do them for you?  In this fully revised second edition of the best-selling classic Automate the Boring Stuff with Python, you'll learn how to use Python to write programs that do in minutes what would take you hours to do by hand--no prior programming experience",
#    'datetime': '2019-10-15T00:00:00.000+09:00',
#    'isbn': '1593279922 9781593279929',
#    'price': 52000,
#    'publisher': 'No Starch Press',
#    'sale_price': 39000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5108738%3Ftimestamp%3D20231107180726',
#    'title': 'Automate the Boring Stuff with Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5108738&q=Automate+the+Boring+Stuff+with+Python'},
#   {'authors': ['라이언 미첼'],
#    'contents': '웹에 존재한다면 그것이 어떤 형태이든 데이터로 추출할 수 있다. 필요한 무기는 이 책과 파이썬뿐. BeautifulSoup, 셀레니움, 테서랙트 등 강력한 파이썬 라이브러리 사용법과 함께 API, 인증, 이미지 및 텍스트 인식, 로그인 처리 등 웹 크롤링의 기초부터 고급 기법까지 종합적으로 다루는 유일한 책. 실제 업무와 생활에 적용할 수 있는 예제를 통해 일상의 데이터 분석가가 될 수 있다.',
#    'datetime': '2016-12-01T00:00:00.000+09:00',
#    'isbn': '8968484694 9788968484698',
#    'price': 24000,
#    'publisher': '한빛미디어',
#    'sale_price': 21600,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F945078%3Ftimestamp%3D20220325195748',
#    'title': '파이썬으로 웹 크롤러 만들기',
#    'translators': ['한선용'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=945078&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9C%BC%EB%A1%9C+%EC%9B%B9+%ED%81%AC%EB%A1%A4%EB%9F%AC+%EB%A7%8C%EB%93%A4%EA%B8%B0'},
#   {'authors': ['James O Knowlton'],
#    'contents': 'This project-based, hands-on book is designed to show you how to use Python to create scripts that are easy to maintain and enhance. Taking a real-world approach, the book explains how Python can be used to solve programming problems. It includes a Python refresher',
#    'datetime': '2014-03-31T00:00:00.000+09:00',
#    'isbn': ' 4800470400821',
#    'price': 37750,
#    'publisher': 'Wrox',
#    'sale_price': -1,
#    'status': '',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F4510052%3Ftimestamp%3D20190301053758',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4510052&q=Python'},
#   {'authors': ['James O Knowlton'],
#    'contents': 'This project-based, hands-on book is designed to show you how to use Python to create scripts that are easy to maintain and enhance. Taking a real-world approach, the book explains how Python can be used to solve programming problems. It includes a Python refresher',
#    'datetime': '2014-03-26T00:00:00.000+09:00',
#    'isbn': ' 4800470419595',
#    'price': 37750,
#    'publisher': 'Wrox',
#    'sale_price': -1,
#    'status': '',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F4763200%3Ftimestamp%3D20190302140912',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4763200&q=Python'},
#   {'authors': ['모리 요시나오'],
#    'contents': '파이썬은 인공지능의 기초 언어로 배우기 쉬우면서 각종 데이터 분석에 사용되는 프로그래밍 언어로 절정의 인기를 누리고 있다. 기존이 파이썬 책이 선뜻 입문하기 어려운 감이 있었다면 이 책은 염소 박사와 강아지 다솜 양의 친근한 일러스트를 도립해 책 전체가 쉬워보이며 실제로도 코드 설명이나 설치법, 버튼 안내가 큼직큼직한 주제의 만화와 대화체 방식으로 구성하여 매우 쉽게 느껴진다.  인터넷에 공개된 데이터를 수집하는 일을 ‘크롤링(Crawling)’, 이 데이터',
#    'datetime': '2021-11-17T00:00:00.000+09:00',
#    'isbn': '8931556896 9788931556896',
#    'price': 17000,
#    'publisher': '성안당',
#    'sale_price': 15300,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5886125%3Ftimestamp%3D20221011091906',
#    'title': '파이썬(Python) 2학년 스크래핑의 구조',
#    'translators': ['이영란'],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5886125&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC%28Python%29+2%ED%95%99%EB%85%84+%EC%8A%A4%ED%81%AC%EB%9E%98%ED%95%91%EC%9D%98+%EA%B5%AC%EC%A1%B0'},
#   {'authors': ['Prateek Joshi'],
#    'contents': '',
#    'datetime': '2017-06-16T00:00:00.000+09:00',
#    'isbn': '1787123219 9781787123212',
#    'price': 135000,
#    'publisher': 'Packt Publishing',
#    'sale_price': 108830,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5213471%3Ftimestamp%3D20230307191532',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5213471&q=Python'},
#   {'authors': ['Phuong VoTH'],
#    'contents': '',
#    'datetime': '2017-04-11T00:00:00.000+09:00',
#    'isbn': '1788290097 9781788290098',
#    'price': 150000,
#    'publisher': 'Packt Publishing',
#    'sale_price': 120930,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5213290%3Ftimestamp%3D20230307162751',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5213290&q=Python'},
#   {'authors': ['Benjamin May'],
#    'contents': '',
#    'datetime': '2017-01-26T00:00:00.000+09:00',
#    'isbn': '1787128180 9781787128187',
#    'price': 127500,
#    'publisher': 'Packt Publishing',
#    'sale_price': 102790,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5213224%3Ftimestamp%3D20230307170305',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5213224&q=Python'},
#   {'authors': ['Needham Timothy C'],
#    'contents': '',
#    'datetime': '2019-03-18T00:00:00.000+09:00',
#    'isbn': '139316093X 9781393160939',
#    'price': 22560,
#    'publisher': 'Whiteflowerpublsihing',
#    'sale_price': 24120,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5635918',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5635918&q=Python'},
#   {'authors': ['Donaldson Toby'],
#    'contents': '',
#    'datetime': '2021-01-01T00:00:00.000+09:00',
#    'isbn': '0321585445 9780321585448',
#    'price': 30340,
#    'publisher': 'Peachpit',
#    'sale_price': 42320,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F2559654%3Ftimestamp%3D20230714191132',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=2559654&q=Python'},
#   {'authors': ['Toby Donaldson'],
#    'contents': '',
#    'datetime': '2013-07-15T00:00:00.000+09:00',
#    'isbn': '0321929551 9780321929556',
#    'price': 58710,
#    'publisher': 'Peachpit Pr',
#    'sale_price': 46530,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3510969%3Ftimestamp%3D20190221122515',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3510969&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2017-03-22T00:00:00.000+09:00',
#    'isbn': ' 9781544877013',
#    'price': 81790,
#    'publisher': '',
#    'sale_price': 58970,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5120921%3Ftimestamp%3D20231210182154',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5120921&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2020-03-31T00:00:00.000+09:00',
#    'isbn': ' 9781393160939',
#    'price': 32660,
#    'publisher': '',
#    'sale_price': 28420,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5658111%3Ftimestamp%3D20231210165248',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5658111&q=Python'},
#   {'authors': ['Masterson Charlie'],
#    'contents': '',
#    'datetime': '2017-03-22T00:00:00.000+09:00',
#    'isbn': '1544877013 9781544877013',
#    'price': 70420,
#    'publisher': 'Createspace Independent Publishing Platform',
#    'sale_price': 62120,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5112434',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5112434&q=Python'},
#   {'authors': ['Fontenrose Joseph'],
#    'contents': '',
#    'datetime': '2012-05-01T00:00:00.000+09:00',
#    'isbn': '8496867730 9788496867734',
#    'price': 68230,
#    'publisher': 'Independent',
#    'sale_price': 59200,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F2990377%3Ftimestamp%3D20230728163237',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=2990377&q=Python'},
#   {'authors': ['Sanders Willard D.'],
#    'contents': '',
#    'datetime': '2020-10-31T00:00:00.000+09:00',
#    'isbn': '180113121X 9781801131216',
#    'price': 26440,
#    'publisher': 'Charlies Law Inc',
#    'sale_price': 28960,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5533146%3Ftimestamp%3D20230918155048',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5533146&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2016-10-26T00:00:00.000+09:00',
#    'isbn': ' 9781539530268',
#    'price': 28890,
#    'publisher': '',
#    'sale_price': 21010,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3903643%3Ftimestamp%3D20230902134847',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3903643&q=Python'},
#   {'authors': ['Brian Moses'],
#    'contents': '',
#    'datetime': '2017-03-23T00:00:00.000+09:00',
#    'isbn': '0995559538 9780995559530',
#    'price': 12850,
#    'publisher': 'Candy Jar Books',
#    'sale_price': 11670,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3633250%3Ftimestamp%3D20230217203443',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3633250&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2017-04-25T00:00:00.000+09:00',
#    'isbn': ' 9781521155486',
#    'price': 32700,
#    'publisher': '',
#    'sale_price': 27800,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5573326%3Ftimestamp%3D20231210172839',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5573326&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2017-01-31T00:00:00.000+09:00',
#    'isbn': ' 9781787125186',
#    'price': 139170,
#    'publisher': '',
#    'sale_price': 139170,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3921889%3Ftimestamp%3D20231210171330',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3921889&q=Python'},
#   {'authors': ['Denis Rothman'],
#    'contents': '',
#    'datetime': '2018-12-21T00:00:00.000+09:00',
#    'isbn': '178995732X 9781789957327',
#    'price': 70000,
#    'publisher': 'Packt Publishing',
#    'sale_price': 60450,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5213486%3Ftimestamp%3D20230307193718',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5213486&q=Python'},
#   {'authors': ['주세페 보나코르소'],
#    'contents': '',
#    'datetime': '2018-12-19T00:00:00.000+09:00',
#    'isbn': '1789957214 9781789957211',
#    'price': 75000,
#    'publisher': 'Packt Publishing',
#    'sale_price': 60450,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5213175%3Ftimestamp%3D20230307193934',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5213175&q=Python'},
#   {'authors': ['Sebastian Raschka'],
#    'contents': '',
#    'datetime': '2017-06-29T00:00:00.000+09:00',
#    'isbn': '1787128571 9781787128576',
#    'price': 135000,
#    'publisher': 'Packt Publishing',
#    'sale_price': 108830,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5211394%3Ftimestamp%3D20230307194506',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5211394&q=Python'},
#   {'authors': ['Jones Paul'],
#    'contents': '',
#    'datetime': '2016-10-26T00:00:00.000+09:00',
#    'isbn': '1539530264 9781539530268',
#    'price': 24010,
#    'publisher': 'Createspace Independent Publishing Platform',
#    'sale_price': -1,
#    'status': '',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F3353153%3Ftimestamp%3D20190220023957',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3353153&q=Python'},
#   {'authors': ['Language Python', 'Academy Icode'],
#    'contents': '',
#    'datetime': '2017-04-25T00:00:00.000+09:00',
#    'isbn': '1521155488 9781521155486',
#    'price': 19880,
#    'publisher': 'Independently Published',
#    'sale_price': 24140,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F5548576',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5548576&q=Python'},
#   {'authors': [],
#    'contents': '',
#    'datetime': '2016-07-04T00:00:00.000+09:00',
#    'isbn': ' 9781535092098',
#    'price': 34890,
#    'publisher': '',
#    'sale_price': 29660,
#    'status': '정상판매',
#    'thumbnail': '',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=5022683&q=Python'},
#   {'authors': ['Createspace Independent Publis'],
#    'contents': '',
#    'datetime': '2016-08-09T00:00:00.000+09:00',
#    'isbn': '1537010956 9781537010953',
#    'price': 28650,
#    'publisher': 'Createspace Independent Publishing Platform',
#    'sale_price': 12660,
#    'status': '정상판매',
#    'thumbnail': '',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3460061&q=Python'},
#   {'authors': ['Createspace Independent Publis'],
#    'contents': '',
#    'datetime': '2016-04-06T00:00:00.000+09:00',
#    'isbn': '1530918154 9781530918157',
#    'price': 18060,
#    'publisher': 'Createspace Independent Publishing Platform',
#    'sale_price': 15980,
#    'status': '정상판매',
#    'thumbnail': '',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=3311554&q=Python'},
#   {'authors': ['Eprogramming (COR)'],
#    'contents': '',
#    'datetime': '2016-07-04T00:00:00.000+09:00',
#    'isbn': '1535092092 9781535092098',
#    'price': 29380,
#    'publisher': 'Createspace Independent Publishing Platform',
#    'sale_price': 25380,
#    'status': '정상판매',
#    'thumbnail': '',
#    'title': 'Python',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=4984139&q=Python'}],
#  'meta': {'is_end': False, 'pageable_count': 1000, 'total_count': 3701}}

# %%
page = 1
isEnd = False

mydata = []

while not isEnd:
    url = urlFmt.format(query=query, page=page, size=size)
    #print(url)

    try:
        r = session.get(url)

        if r.status_code !=200:
            msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
            raise Exception(msg)

    except Exception as e:
        print("접속에 실패했습니다.")
        print(e)  

        break

    r.encoding = "utf-8"
    mydict = json.loads(r.text)

    mydata += mydict['documents']
    print("%d 페이지로부터 %d건의 데이터를 수집했습니다." % (page,len(mydict['documents'])))

    isEnd = mydict['meta']['is_end']

    page += 1

print("fin :)")
# Out:
# 1 페이지로부터 50건의 데이터를 수집했습니다.
# 2 페이지로부터 50건의 데이터를 수집했습니다.
# 3 페이지로부터 50건의 데이터를 수집했습니다.
# 4 페이지로부터 50건의 데이터를 수집했습니다.
# 5 페이지로부터 50건의 데이터를 수집했습니다.
# 6 페이지로부터 50건의 데이터를 수집했습니다.
# 7 페이지로부터 50건의 데이터를 수집했습니다.
# 8 페이지로부터 50건의 데이터를 수집했습니다.
# 9 페이지로부터 50건의 데이터를 수집했습니다.
# 10 페이지로부터 50건의 데이터를 수집했습니다.
# 11 페이지로부터 50건의 데이터를 수집했습니다.
# 12 페이지로부터 50건의 데이터를 수집했습니다.
# 13 페이지로부터 50건의 데이터를 수집했습니다.
# 14 페이지로부터 50건의 데이터를 수집했습니다.
# 15 페이지로부터 50건의 데이터를 수집했습니다.
# 16 페이지로부터 50건의 데이터를 수집했습니다.
# 17 페이지로부터 50건의 데이터를 수집했습니다.
# 18 페이지로부터 50건의 데이터를 수집했습니다.
# 19 페이지로부터 50건의 데이터를 수집했습니다.
# 20 페이지로부터 50건의 데이터를 수집했습니다.
# fin :)

# %%
with open("%s_책_검색결과.csv" % query, 'w', encoding='utf-8') as f:
    f.write("제목,저자,출판사,정가,판매가,출간일\n")

    for i,v in enumerate(mydata):
        authors, contents, datetime, isbn, price, publisher,sale_price, status, thumbnail,title,translators,url=v.values()
        authors = "/".join(authors)
        #print(authors)
        
        # 날짜값이 ISO형식인 경우 python의 datetime객체로 변환하기 위해 fromisoformat() 메서드를 사용한다.
        #print(datetime)
        iso_date = dt.datetime.fromisoformat(datetime)
        #print(iso_date.strftime("%Y-%m-%d"))
        
        f.write("%s,%s,%s,%s,%s,%s\n" % (title, authors, publisher, price, sale_price, iso_date.strftime("%Y-%m-%d")))
        #break
    
print("fin :)")
