# %% [markdown]
# # 블로그 컨텐츠 수집

# %%
import datetime as dt
import requests
from bs4 import BeautifulSoup

# %%
url = "https://blog.hossam.kr"

# %%
session = requests.Session()

session.headers.update({
    "Referer": "",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
})

# %%
try:
    r = session.get(url)

    if r.status_code != 200:
        msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
        raise Exception(msg)
except Exception as e:
    print("접속에 실패했습니다.")
    print(e)

r.encoding = "utf-8"
soup = BeautifulSoup(r.text)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-WZ7PJ3DB');
#         </script>
# <!-- End Google Tag Manager -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-HJRT9MJD76"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-HJRT9MJD76');
#         </script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-5964579162086633"></script>
# <meta charset="utf-8"/>
# <meta content="ca-pub-5964579162086633" name="google-adsense-account"/>
# <meta content="notranslate" name="google"/>
# <title>호쌤코딩클럽</title>
# <meta content="프로그래밍 전문 강사 호쌤(이광호)의 블로그 입니다." name="description">
# <!-- Begin Jekyll SEO tag v2.8.0 -->
# <meta content="Jekyll v3.9.3" name="generator">
# <meta content="호쌤코딩클럽" property="og:title"/>
# <meta content="LEE KWANGHO" name="author"/>
# <meta content="ko_Kr" property="og:locale"/>
# <meta content="프로그래밍 전문 강사 호쌤(이광호)의 블로그 입니다." name="description"/>
# <meta content="프로그래밍 전문 강사 호쌤(이광호)의 블로그 입니다." property="og:description"/>
# <link href="https://blog.hossam.kr/" rel="canonical"/>
# <meta content="https://blog.hossam.kr/" property="og:url"/>
# <meta content="호쌤코딩클럽" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <link href="https://blog.hossam.kr/blog/page2/" rel="next"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="호쌤코딩클럽" property="twitter:title"/>
# <script type="application/ld+json">
# {"@context":"https://schema.org","@type":"WebSite","author":{"@type":"Person","name":"LEE KWANGHO"},"description":"프로그래밍 전문 강사 호쌤(이광호)의 블로그 입니다.","headline":"호쌤코딩클럽","name":"호쌤코딩클럽","url":"https://blog.hossam.kr/"}</script>
# <!-- End Jekyll SEO tag -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="blendTrans(duration=0.3)" http-equiv="page-enter"/>
# <meta content="blendTrans(duration=0.3)" http-equiv="page-exit"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="//fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
# <link href="//fonts.googleapis.com/css2?family=Noto+Sans+KR:wght@100;300;400;500;700;900&amp;display=swap" rel="stylesheet"/>
# <link href="/css/main.min.css" rel="stylesheet">
# <link href="https://blog.hossam.kr/" rel="canonical">
# <link href="https://blog.hossam.kr/feed.xml" rel="alternate" title="호쌤코딩클럽 Feed" type="application/rss+xml"/>
# </link></link></meta></meta></head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WZ7PJ3DB" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="progress-container">
# <div class="progress-bar" id="myBar"></div>
# </div>
# <nav class="site-navigation" id="top">
# <div class="inner">
# <button aria-expanded="false" id="menu-toggle">Menu</button>
# <div class="nav-menu">
# <ul class="menu">
# <li class="nav-current">
# <a class="nav-current" href="/">Home</a>
# </li>
# <li class="">
# <a class="" href="/about/">About</a>
# </li>
# <li class="">
# <a class="" href="/tags/">Archives</a>
# </li>
# </ul>
# </div>
# <!-- .nav-menu -->
# <a class="print-button fill-horizontal" href="#" onclick="window.print(); return false;"><span class="screen-reader-text">Print</span></a>
# <a class="subscribe-button fa-feed square fill-horizontal" href="/feed.xml"><span class="screen-reader-text">Subscribe</span></a>
# </div>
# <!-- .inner -->
# </nav>
# <!-- .site-navigation -->
# <header class="site-header">
# <div class="inner">
# <h1 class="site-title">
# <a class="logo-text" href="/">호쌤코딩클럽</a>
# </h1>
# <p class="site-description">Thoughts, stories and ideas.</p>
# </div>
# <!-- .inner -->
# </header>
# <div class="site-content">
# <div class="inner">
# <main class="site-main">
# <article class="post">
# <header class="entry-header">
# <div class="entry-header-wrap">
# <a class="post-thumbnail" href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/"><img alt="[Toy Project] 서버 가동 설정 수정 " src="/images/posts/index-toyproject.jpg"/></a>
# <h2 class="entry-title"><a href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/" rel="bookmark" title="Permanent Link to /2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/">[Toy Project] 서버 가동 설정 수정</a></h2>
# </div><!-- .entry-header-wrap -->
# <div class="entry-meta">
#                         by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-21">August 21, 2023</time>
# </div><!-- .entry-meta -->
# </header><!-- .entry-header -->
# <div class="entry-content">
# <p>납품했던 웹 사이트에 대해 몇 가지 수정사항이 발생하였다. 이를 처리하는 과정에서 진행중인 토이프로젝트의 설정도 수정해야 할 부분이 발견되었다.</p>
# <p class="read-more"><a class="more-link" href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/" title="read more">read more</a></p>
# </div><!-- .entry-content -->
# <footer class="entry-footer">
# <div class="tag-links">
#                         Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
# </div>
# </footer><!-- .entry-footer -->
# </article><!-- .post -->
# <article class="post">
# <header class="entry-header">
# <div class="entry-header-wrap">
# <a class="post-thumbnail" href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/"><img alt="[Toy Project] Next.js와 Express 병합 " src="/images/posts/index-toyproject.jpg"/></a>
# <h2 class="entry-title"><a href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/" rel="bookmark" title="Permanent Link to /2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/">[Toy Project] Next.js와 Express 병합</a></h2>
# </div><!-- .entry-header-wrap -->
# <div class="entry-meta">
#                         by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-20">August 20, 2023</time>
# </div><!-- .entry-meta -->
# </header><!-- .entry-header -->
# <div class="entry-content">
# <p>Backend와 Frontend가 각각 독립적인 시스템으로 구축되어 서로 연동하는 것이 이상적인 형태이겠지만 웹호스팅을 사용하는 경우 두개의 호스팅 계정을 만들지 않은 이상은 하나의 웹 서버안에서 Frontend와 Backend를 모두 처리해야 한다. 그렇기 때문에 우선적으로 구성해야 하는 환경은 Next.js에 백엔드 시스템을 병합하는 것이다.</p>
# <p>Next.js 자체적으로 API Route 기능을 제공하기는 하지만 백엔드 시스템으로 사용하기에는 다소 부족한 부분이 있기 때문에 Express를 병합하기로 하였다.</p>
# <p class="read-more"><a class="more-link" href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/" title="read more">read more</a></p>
# </div><!-- .entry-content -->
# <footer class="entry-footer">
# <div class="tag-links">
#                         Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
# </div>
# </footer><!-- .entry-footer -->
# </article><!-- .post -->
# <article class="post">
# <header class="entry-header">
# <div class="entry-header-wrap">
# <a class="post-thumbnail" href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/"><img alt="[Toy Project] 토이 프로젝트 시작 " src="/images/posts/index-toyproject.jpg"/></a>
# <h2 class="entry-title"><a href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/" rel="bookmark" title="Permanent Link to /2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/">[Toy Project] 토이 프로젝트 시작</a></h2>
# </div><!-- .entry-header-wrap -->
# <div class="entry-meta">
#                         by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-17">August 17, 2023</time>
# </div><!-- .entry-meta -->
# </header><!-- .entry-header -->
# <div class="entry-content">
# <p>지난주에 끝마친 웹 사이트 외주 작업을 <code class="language-plaintext highlighter-rouge">Next.js + Express</code> 형태의 Fullstack으로 혼자 진행했었다. 전에는 혼자서 진행해야 하는 외주 작업일 경우 PHP기반의 Codeignitor3를 채택했었지만 워낙 노후된 Framework이기도 하고 Codeigniter4나 Laravel로 전향하면서 겪어야 하는 러닝커브가 효율적이지 않을것 같아서 자주 관심을 두고 있던 Next.js와 Express의 조합으로 결정했다.</p>
# <p>하지만 내가 너무 쉽게 생각했던것인지… 국내 웹 호스팅 환경에서 이 조합을 사용하기 위해서 겪을 수 밖에 없었던 시행착오들이 너무 많았다.</p>
# <p>프로젝트를 마무리하고 겪었던 시행착오와 코드상에서 아쉬웠던 부분들을 보완하여 나만의 Framework 템플릿을 구성하고자 한다. 해당 작업에서의 경험을 하나씩 연제해 보려고 오랜만에 포스트를 작성한다.</p>
# <p class="read-more"><a class="more-link" href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/" title="read more">read more</a></p>
# </div><!-- .entry-content -->
# <footer class="entry-footer">
# <div class="tag-links">
#                         Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
# </div>
# </footer><!-- .entry-footer -->
# </article><!-- .post -->
# <article class="post">
# <header class="entry-header">
# <div class="entry-header-wrap">
# <a class="post-thumbnail" href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/"><img alt="[Mac] OpenJDK 설치하기 " src="/images/posts/index-mac.jpg"/></a>
# <h2 class="entry-title"><a href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/" rel="bookmark" title="Permanent Link to /2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/">[Mac] OpenJDK 설치하기</a></h2>
# </div><!-- .entry-header-wrap -->
# <div class="entry-meta">
#                         by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-07-13">July 13, 2023</time>
# </div><!-- .entry-meta -->
# </header><!-- .entry-header -->
# <div class="entry-content">
# <p>JDK(Java Development Kit)은 Java 컴파일러와 Java Virtual Machine을 포함하는 자바 프로그래밍의 필수 도구 입니다.</p>
# <p>Oracle JDK와 Open JDK 두 종류가 있지만 Oracle JDK는 라이센스 문제로 인해 최근에는 Open JDK를 주로 사용하고 있습니다.</p>
# <p class="read-more"><a class="more-link" href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/" title="read more">read more</a></p>
# </div><!-- .entry-content -->
# <footer class="entry-footer">
# <div class="tag-links">
#                         Tags: <a href="/tags/index.html#Mac" rel="tag" title="Pages tagged Mac">Mac</a>
# </div>
# </footer><!-- .entry-footer -->
# </article><!-- .post -->
# <article class="post">
# <header class="entry-header">
# <div class="entry-header-wrap">
# <a class="post-thumbnail" href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/"><img alt="[Mac] 개발환경 구성 필수 요소 " src="/images/posts/index-mac.jpg"/></a>
# <h2 class="entry-title"><a href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/" rel="bookmark" title="Permanent Link to /2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/">[Mac] 개발환경 구성 필수 요소</a></h2>
# </div><!-- .entry-header-wrap -->
# <div class="entry-meta">
#                         by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-07-12">July 12, 2023</time>
# </div><!-- .entry-meta -->
# </header><!-- .entry-header -->
# <div class="entry-content">
# <p>직훈교육을 진행하다보면 맥북을 가지고 교육에 참여하는 경우를 종종 보게 됩니다. 하지만 거의 모든 훈련기관은 Windows PC를 강의실에 구비해 놓고 있으며 대부분의 훈련생들은 Windows 환경에서 수업에 참여하기 때문에 맥북을 사용하다 보면 종종 수업 내용과 프로그램 설치 방법에서 차이를 겪으면서 수업 내용을 놓치기 쉽습니다.</p>
# <p>컴퓨터 자체에 익숙해서 맥을 능숙하게 다룬다면 수업 내용과의 차이를 스스로 보완할 수 있지만 컴퓨터에 익숙하지 않은 상태에서 단순히 코딩을 하기에 맥이 좋다는 말을 듣고 덜컥 구입하거나 맥북이 이쁘다는 이유로 구입한 경우는 훈련을 진행하면서 무척 난감함을 느끼게 됩니다. 특정 훈련생에게 설치 과정을 별도로 처음부터 알려주기에는 시간 비용이 무척 오래 걸리기 때문입니다.</p>
# <p>이 포스팅에서는 MacOS 환경에서 코딩을 진행하고자 할 경우 필수로 설치해야 하는 요소들을 소개합니다.</p>
# <p class="read-more"><a class="more-link" href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/" title="read more">read more</a></p>
# </div><!-- .entry-content -->
# <footer class="entry-footer">
# <div class="tag-links">
#                         Tags: <a href="/tags/index.html#Mac" rel="tag" title="Pages tagged Mac">Mac</a>
# </div>
# </footer><!-- .entry-footer -->
# </article><!-- .post -->
# <nav class="pagination">
# <h2 class="screen-reader-text">Posts navigation</h2>
# <span class="page-number">Page 1 of 22</span>
# <a class="older-posts fa-chevron-right square fill-horizontal" href="/blog/page2/"><span class="screen-reader-text">Older Posts</span></a>
# </nav><!-- .pagination -->
# </main><!-- .site-main -->
# <aside class="sidebar">
# <section class="widget widget-text">
# <p>
# <a href="https://blog.hossam.kr" target="_blank"><img alt="Optional Banner Ad" src="/images/profile.png"/></a>
# </p>
# </section>
# <section class="widget widget-text">
# <h2 class="widget-title">About 호쌤(이광호)</h2>
# <p>메가스터디IT아카데미에서 Java, Spring, Python, Frontend 등을 강의하는 IT 전문 강사이자 프리렌서 개발자 입니다.<br/><a href="https://www.youtube.com/@hossam-codingclub" target="_blank">https://www.youtube.com/@hossam-codingclub</a></p>
# </section>
# <section class="widget widget-recent-posts">
# <h2 class="widget-title">Latest Posts</h2>
# <ul class="recent-posts">
# <li class="recent-item"><a href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/">[Toy Project] 서버 가동 설정 수정</a> <span>August 21, 2023</span></li>
# <li class="recent-item"><a href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/">[Toy Project] Next.js와 Express 병합</a> <span>August 20, 2023</span></li>
# <li class="recent-item"><a href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/">[Toy Project] 토이 프로젝트 시작</a> <span>August 17, 2023</span></li>
# <li class="recent-item"><a href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/">[Mac] OpenJDK 설치하기</a> <span>July 13, 2023</span></li>
# <li class="recent-item"><a href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/">[Mac] 개발환경 구성 필수 요소</a> <span>July 12, 2023</span></li>
# </ul>
# <!-- .recent-posts -->
# </section>
# <!-- .widget-recent-posts -->
# <!--Create a sorted array of tags-->
# <section class="widget widget-tags">
# <h2 class="widget-title">Tags</h2>
# <div class="tagcloud">
# <a href="/tags/#Database">Database</a>
# <a href="/tags/#Javascript">Javascript</a>
# <a href="/tags/#Linux">Linux</a>
# <a href="/tags/#Mac">Mac</a>
# <a href="/tags/#Programming">Programming</a>
# <a href="/tags/#R">R</a>
# <a href="/tags/#Toy+Project">Toy Project</a>
# <a href="/tags/#Web+Publishing">Web Publishing</a>
# <a href="/tags/#Windows">Windows</a>
# <a href="/tags/#jQuery">jQuery</a>
# <a href="/tags/#%EC%BB%B4%ED%93%A8%ED%84%B0%ED%99%9C%EC%9A%A9">컴퓨터활용</a>
# </div>
# <!-- .tagcloud -->
# </section>
# <!-- .widget -->
# </aside>
# <!-- .sidebar -->
# </div><!-- .inner -->
# </div><!-- .site-content -->
# <footer class="site-footer">
# <div class="inner">
# <div class="social-links">
# <a class="fa-github-alt square fill-horizontal" href="https://github.com/leekh4232"><span class="screen-reader-text">GitHub</span></a>
# <a class="fa-youtube-play square fill-horizontal" href="https://www.youtube.com/@hossam-codingclub"><span class="screen-reader-text">Youtube</span></a>
# <a class="fa-instagram square fill-horizontal" href="http://instagram.com/leekh4232"><span class="screen-reader-text">Instagram</span></a>
# <a class="fa-feed square fill-horizontal" href="/feed.xml"><span class="screen-reader-text">RSS</span></a>
# </div><!-- .social-links -->
# <div class="site-info">
#             © <a href="/">호쌤코딩클럽</a> all rights reserved. <br/>Powered by <a href="https://jekyllrb.com/" target="_blank">Jekyll</a>.
#             <a class="fa-chevron-up top-link square fill-horizontal" href="#top" id="top-link"><span class="screen-reader-text">Back to the top</span></a>
# </div><!-- .site-info -->
# </div><!-- .inner -->
# </footer><!-- .site-footer -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
# <script src="/js/plugins.js" type="text/javascript"></script>
# <script src="/js/custom.js" type="text/javascript"></script>
# <!-- Add LaTex function -->
# <script async="" src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/latest.js?config=TeX-MML-AM_CHTML" type="text/javascript"></script>
# <script type="text/x-mathjax-config">
#     MathJax.Hub.Config({
#         extensions: ["tex2jax.js"],
#         jax: ["input/TeX", "output/HTML-CSS"],
#         tex2jax: { inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#         displayMath: [ ['$$','$$'], ["\\[","\\]"] ],
#         processEscapes: true },
#         "HTML-CSS": { availableFonts: ["TeX"] }
#     });
# </script>
# <script>
#     const progressFunc = () => {
#         const winScroll = document.body.scrollTop || document.documentElement.scrollTop;
#         const height = document.documentElement.scrollHeight - document.documentElement.clientHeight;
#         const scrolled = (winScroll / height) * 100;
#         document.getElementById("myBar").style.width = scrolled + "%";
#     };
#
#     window.addEventListener("load", progressFunc);
#     window.addEventListener("scroll", progressFunc);
# </script>
# </body>
# </html>

# %%
post = soup.select(".post")
print("추출한 컨텐츠의 수:", len(post))
post
# Out:
# 추출한 컨텐츠의 수: 5
# [<article class="post">
#  <header class="entry-header">
#  <div class="entry-header-wrap">
#  <a class="post-thumbnail" href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/"><img alt="[Toy Project] 서버 가동 설정 수정 " src="/images/posts/index-toyproject.jpg"/></a>
#  <h2 class="entry-title"><a href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/" rel="bookmark" title="Permanent Link to /2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/">[Toy Project] 서버 가동 설정 수정</a></h2>
#  </div><!-- .entry-header-wrap -->
#  <div class="entry-meta">
#                          by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-21">August 21, 2023</time>
#  </div><!-- .entry-meta -->
#  </header><!-- .entry-header -->
#  <div class="entry-content">
#  <p>납품했던 웹 사이트에 대해 몇 가지 수정사항이 발생하였다. 이를 처리하는 과정에서 진행중인 토이프로젝트의 설정도 수정해야 할 부분이 발견되었다.</p>
#  <p class="read-more"><a class="more-link" href="/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/" title="read more">read more</a></p>
#  </div><!-- .entry-content -->
#  <footer class="entry-footer">
#  <div class="tag-links">
#                          Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
#  </div>
#  </footer><!-- .entry-footer -->
#  </article>,
#  <article class="post">
#  <header class="entry-header">
#  <div class="entry-header-wrap">
#  <a class="post-thumbnail" href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/"><img alt="[Toy Project] Next.js와 Express 병합 " src="/images/posts/index-toyproject.jpg"/></a>
#  <h2 class="entry-title"><a href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/" rel="bookmark" title="Permanent Link to /2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/">[Toy Project] Next.js와 Express 병합</a></h2>
#  </div><!-- .entry-header-wrap -->
#  <div class="entry-meta">
#                          by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-20">August 20, 2023</time>
#  </div><!-- .entry-meta -->
#  </header><!-- .entry-header -->
#  <div class="entry-content">
#  <p>Backend와 Frontend가 각각 독립적인 시스템으로 구축되어 서로 연동하는 것이 이상적인 형태이겠지만 웹호스팅을 사용하는 경우 두개의 호스팅 계정을 만들지 않은 이상은 하나의 웹 서버안에서 Frontend와 Backend를 모두 처리해야 한다. 그렇기 때문에 우선적으로 구성해야 하는 환경은 Next.js에 백엔드 시스템을 병합하는 것이다.</p>
#  <p>Next.js 자체적으로 API Route 기능을 제공하기는 하지만 백엔드 시스템으로 사용하기에는 다소 부족한 부분이 있기 때문에 Express를 병합하기로 하였다.</p>
#  <p class="read-more"><a class="more-link" href="/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/" title="read more">read more</a></p>
#  </div><!-- .entry-content -->
#  <footer class="entry-footer">
#  <div class="tag-links">
#                          Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
#  </div>
#  </footer><!-- .entry-footer -->
#  </article>,
#  <article class="post">
#  <header class="entry-header">
#  <div class="entry-header-wrap">
#  <a class="post-thumbnail" href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/"><img alt="[Toy Project] 토이 프로젝트 시작 " src="/images/posts/index-toyproject.jpg"/></a>
#  <h2 class="entry-title"><a href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/" rel="bookmark" title="Permanent Link to /2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/">[Toy Project] 토이 프로젝트 시작</a></h2>
#  </div><!-- .entry-header-wrap -->
#  <div class="entry-meta">
#                          by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-08-17">August 17, 2023</time>
#  </div><!-- .entry-meta -->
#  </header><!-- .entry-header -->
#  <div class="entry-content">
#  <p>지난주에 끝마친 웹 사이트 외주 작업을 <code class="language-plaintext highlighter-rouge">Next.js + Express</code> 형태의 Fullstack으로 혼자 진행했었다. 전에는 혼자서 진행해야 하는 외주 작업일 경우 PHP기반의 Codeignitor3를 채택했었지만 워낙 노후된 Framework이기도 하고 Codeigniter4나 Laravel로 전향하면서 겪어야 하는 러닝커브가 효율적이지 않을것 같아서 자주 관심을 두고 있던 Next.js와 Express의 조합으로 결정했다.</p>
#  <p>하지만 내가 너무 쉽게 생각했던것인지… 국내 웹 호스팅 환경에서 이 조합을 사용하기 위해서 겪을 수 밖에 없었던 시행착오들이 너무 많았다.</p>
#  <p>프로젝트를 마무리하고 겪었던 시행착오와 코드상에서 아쉬웠던 부분들을 보완하여 나만의 Framework 템플릿을 구성하고자 한다. 해당 작업에서의 경험을 하나씩 연제해 보려고 오랜만에 포스트를 작성한다.</p>
#  <p class="read-more"><a class="more-link" href="/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/" title="read more">read more</a></p>
#  </div><!-- .entry-content -->
#  <footer class="entry-footer">
#  <div class="tag-links">
#                          Tags: <a href="/tags/index.html#Toy+Project" rel="tag" title="Pages tagged Toy Project">Toy Project</a>
#  </div>
#  </footer><!-- .entry-footer -->
#  </article>,
#  <article class="post">
#  <header class="entry-header">
#  <div class="entry-header-wrap">
#  <a class="post-thumbnail" href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/"><img alt="[Mac] OpenJDK 설치하기 " src="/images/posts/index-mac.jpg"/></a>
#  <h2 class="entry-title"><a href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/" rel="bookmark" title="Permanent Link to /2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/">[Mac] OpenJDK 설치하기</a></h2>
#  </div><!-- .entry-header-wrap -->
#  <div class="entry-meta">
#                          by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-07-13">July 13, 2023</time>
#  </div><!-- .entry-meta -->
#  </header><!-- .entry-header -->
#  <div class="entry-content">
#  <p>JDK(Java Development Kit)은 Java 컴파일러와 Java Virtual Machine을 포함하는 자바 프로그래밍의 필수 도구 입니다.</p>
#  <p>Oracle JDK와 Open JDK 두 종류가 있지만 Oracle JDK는 라이센스 문제로 인해 최근에는 Open JDK를 주로 사용하고 있습니다.</p>
#  <p class="read-more"><a class="more-link" href="/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/" title="read more">read more</a></p>
#  </div><!-- .entry-content -->
#  <footer class="entry-footer">
#  <div class="tag-links">
#                          Tags: <a href="/tags/index.html#Mac" rel="tag" title="Pages tagged Mac">Mac</a>
#  </div>
#  </footer><!-- .entry-footer -->
#  </article>,
#  <article class="post">
#  <header class="entry-header">
#  <div class="entry-header-wrap">
#  <a class="post-thumbnail" href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/"><img alt="[Mac] 개발환경 구성 필수 요소 " src="/images/posts/index-mac.jpg"/></a>
#  <h2 class="entry-title"><a href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/" rel="bookmark" title="Permanent Link to /2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/">[Mac] 개발환경 구성 필수 요소</a></h2>
#  </div><!-- .entry-header-wrap -->
#  <div class="entry-meta">
#                          by <span class="post-author">호쌤(이광호)</span> on <time class="published" datetime="2023-07-12">July 12, 2023</time>
#  </div><!-- .entry-meta -->
#  </header><!-- .entry-header -->
#  <div class="entry-content">
#  <p>직훈교육을 진행하다보면 맥북을 가지고 교육에 참여하는 경우를 종종 보게 됩니다. 하지만 거의 모든 훈련기관은 Windows PC를 강의실에 구비해 놓고 있으며 대부분의 훈련생들은 Windows 환경에서 수업에 참여하기 때문에 맥북을 사용하다 보면 종종 수업 내용과 프로그램 설치 방법에서 차이를 겪으면서 수업 내용을 놓치기 쉽습니다.</p>
#  <p>컴퓨터 자체에 익숙해서 맥을 능숙하게 다룬다면 수업 내용과의 차이를 스스로 보완할 수 있지만 컴퓨터에 익숙하지 않은 상태에서 단순히 코딩을 하기에 맥이 좋다는 말을 듣고 덜컥 구입하거나 맥북이 이쁘다는 이유로 구입한 경우는 훈련을 진행하면서 무척 난감함을 느끼게 됩니다. 특정 훈련생에게 설치 과정을 별도로 처음부터 알려주기에는 시간 비용이 무척 오래 걸리기 때문입니다.</p>
#  <p>이 포스팅에서는 MacOS 환경에서 코딩을 진행하고자 할 경우 필수로 설치해야 하는 요소들을 소개합니다.</p>
#  <p class="read-more"><a class="more-link" href="/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/" title="read more">read more</a></p>
#  </div><!-- .entry-content -->
#  <footer class="entry-footer">
#  <div class="tag-links">
#                          Tags: <a href="/tags/index.html#Mac" rel="tag" title="Pages tagged Mac">Mac</a>
#  </div>
#  </footer><!-- .entry-footer -->
#  </article>]

# %%
mydata = []

for i, v in enumerate(post):
    #print(v)

    entryTitle = v.select(".entry-title a")
    #print(entryTitle)

    title = entryTitle[0].text.strip()
    #print(title)

    if "href" in entryTitle[0].attrs:
        href = entryTitle[0].attrs['href']

        if url not in href:
            href = "%s%s" % (url, href)
    else:
        href = None
    #print(href)            
    published = v.select(".published")
    #print(published)

    datetime = published[0].attrs['datetime']
    #print(datetime)

    entryContent = v.select(".entry-content p:not(.read-more)")
    #print(entryContent)

    text = ""
    for j, w in enumerate(entryContent):
        text += " " + w.text.strip() if j > 0 else w.text.strip()
    #print(text)

    tagLinks = v.select(".tag-links a")
    #print(tagLinks) 

    for j, w in enumerate(tagLinks):
        tagLinks[j] = w.text.strip()

    #print(tagLinks)
    tags = ",".join(tagLinks)
    #print(tags)

    mydict = {
        "title": title,
        "href": href,
        "datetime": datetime,
        "text": text,
        "tags": tags
    }
    print(mydict)

    mydata.append(mydict)       

mydata
# Out:
# {'title': '[Toy Project] 서버 가동 설정 수정', 'href': 'https://blog.hossam.kr/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/', 'datetime': '2023-08-21', 'text': '납품했던 웹 사이트에 대해 몇 가지 수정사항이 발생하였다. 이를 처리하는 과정에서 진행중인 토이프로젝트의 설정도 수정해야 할 부분이 발견되었다.', 'tags': 'Toy Project'}
# {'title': '[Toy Project] Next.js와 Express 병합', 'href': 'https://blog.hossam.kr/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/', 'datetime': '2023-08-20', 'text': 'Backend와 Frontend가 각각 독립적인 시스템으로 구축되어 서로 연동하는 것이 이상적인 형태이겠지만 웹호스팅을 사용하는 경우 두개의 호스팅 계정을 만들지 않은 이상은 하나의 웹 서버안에서 Frontend와 Backend를 모두 처리해야 한다. 그렇기 때문에 우선적으로 구성해야 하는 환경은 Next.js에 백엔드 시스템을 병합하는 것이다. Next.js 자체적으로 API Route 기능을 제공하기는 하지만 백엔드 시스템으로 사용하기에는 다소 부족한 부분이 있기 때문에 Express를 병합하기로 하였다.', 'tags': 'Toy Project'}
# {'title': '[Toy Project] 토이 프로젝트 시작', 'href': 'https://blog.hossam.kr/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/', 'datetime': '2023-08-17', 'text': '지난주에 끝마친 웹 사이트 외주 작업을 Next.js + Express 형태의 Fullstack으로 혼자 진행했었다. 전에는 혼자서 진행해야 하는 외주 작업일 경우 PHP기반의 Codeignitor3를 채택했었지만 워낙 노후된 Framework이기도 하고 Codeigniter4나 Laravel로 전향하면서 겪어야 하는 러닝커브가 효율적이지 않을것 같아서 자주 관심을 두고 있던 Next.js와 Express의 조합으로 결정했다. 하지만 내가 너무 쉽게 생각했던것인지… 국내 웹 호스팅 환경에서 이 조합을 사용하기 위해서 겪을 수 밖에 없었던 시행착오들이 너무 많았다. 프로젝트를 마무리하고 겪었던 시행착오와 코드상에서 아쉬웠던 부분들을 보완하여 나만의 Framework 템플릿을 구성하고자 한다. 해당 작업에서의 경험을 하나씩 연제해 보려고 오랜만에 포스트를 작성한다.', 'tags': 'Toy Project'}
# {'title': '[Mac] OpenJDK 설치하기', 'href': 'https://blog.hossam.kr/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/', 'datetime': '2023-07-13', 'text': 'JDK(Java Development Kit)은 Java 컴파일러와 Java Virtual Machine을 포함하는 자바 프로그래밍의 필수 도구 입니다. Oracle JDK와 Open JDK 두 종류가 있지만 Oracle JDK는 라이센스 문제로 인해 최근에는 Open JDK를 주로 사용하고 있습니다.', 'tags': 'Mac'}
# {'title': '[Mac] 개발환경 구성 필수 요소', 'href': 'https://blog.hossam.kr/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/', 'datetime': '2023-07-12', 'text': '직훈교육을 진행하다보면 맥북을 가지고 교육에 참여하는 경우를 종종 보게 됩니다. 하지만 거의 모든 훈련기관은 Windows PC를 강의실에 구비해 놓고 있으며 대부분의 훈련생들은 Windows 환경에서 수업에 참여하기 때문에 맥북을 사용하다 보면 종종 수업 내용과 프로그램 설치 방법에서 차이를 겪으면서 수업 내용을 놓치기 쉽습니다. 컴퓨터 자체에 익숙해서 맥을 능숙하게 다룬다면 수업 내용과의 차이를 스스로 보완할 수 있지만 컴퓨터에 익숙하지 않은 상태에서 단순히 코딩을 하기에 맥이 좋다는 말을 듣고 덜컥 구입하거나 맥북이 이쁘다는 이유로 구입한 경우는 훈련을 진행하면서 무척 난감함을 느끼게 됩니다. 특정 훈련생에게 설치 과정을 별도로 처음부터 알려주기에는 시간 비용이 무척 오래 걸리기 때문입니다. 이 포스팅에서는 MacOS 환경에서 코딩을 진행하고자 할 경우 필수로 설치해야 하는 요소들을 소개합니다.', 'tags': 'Mac'}
# [{'title': '[Toy Project] 서버 가동 설정 수정',
#   'href': 'https://blog.hossam.kr/2023/08/21/Toy-%EC%84%9C%EB%B2%84_%EA%B0%80%EB%8F%99_%EC%84%A4%EC%A0%95_%EC%88%98%EC%A0%95/',
#   'datetime': '2023-08-21',
#   'text': '납품했던 웹 사이트에 대해 몇 가지 수정사항이 발생하였다. 이를 처리하는 과정에서 진행중인 토이프로젝트의 설정도 수정해야 할 부분이 발견되었다.',
#   'tags': 'Toy Project'},
#  {'title': '[Toy Project] Next.js와 Express 병합',
#   'href': 'https://blog.hossam.kr/2023/08/20/Toy-Next.js+Express-%EB%B3%91%ED%95%A9/',
#   'datetime': '2023-08-20',
#   'text': 'Backend와 Frontend가 각각 독립적인 시스템으로 구축되어 서로 연동하는 것이 이상적인 형태이겠지만 웹호스팅을 사용하는 경우 두개의 호스팅 계정을 만들지 않은 이상은 하나의 웹 서버안에서 Frontend와 Backend를 모두 처리해야 한다. 그렇기 때문에 우선적으로 구성해야 하는 환경은 Next.js에 백엔드 시스템을 병합하는 것이다. Next.js 자체적으로 API Route 기능을 제공하기는 하지만 백엔드 시스템으로 사용하기에는 다소 부족한 부분이 있기 때문에 Express를 병합하기로 하였다.',
#   'tags': 'Toy Project'},
#  {'title': '[Toy Project] 토이 프로젝트 시작',
#   'href': 'https://blog.hossam.kr/2023/08/17/Toy-%ED%86%A0%EC%9D%B4%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8-%EC%8B%9C%EC%9E%91/',
#   'datetime': '2023-08-17',
#   'text': '지난주에 끝마친 웹 사이트 외주 작업을 Next.js + Express 형태의 Fullstack으로 혼자 진행했었다. 전에는 혼자서 진행해야 하는 외주 작업일 경우 PHP기반의 Codeignitor3를 채택했었지만 워낙 노후된 Framework이기도 하고 Codeigniter4나 Laravel로 전향하면서 겪어야 하는 러닝커브가 효율적이지 않을것 같아서 자주 관심을 두고 있던 Next.js와 Express의 조합으로 결정했다. 하지만 내가 너무 쉽게 생각했던것인지… 국내 웹 호스팅 환경에서 이 조합을 사용하기 위해서 겪을 수 밖에 없었던 시행착오들이 너무 많았다. 프로젝트를 마무리하고 겪었던 시행착오와 코드상에서 아쉬웠던 부분들을 보완하여 나만의 Framework 템플릿을 구성하고자 한다. 해당 작업에서의 경험을 하나씩 연제해 보려고 오랜만에 포스트를 작성한다.',
#   'tags': 'Toy Project'},
#  {'title': '[Mac] OpenJDK 설치하기',
#   'href': 'https://blog.hossam.kr/2023/07/13/Mac-OpenJDK-%EC%84%A4%EC%B9%98/',
#   'datetime': '2023-07-13',
#   'text': 'JDK(Java Development Kit)은 Java 컴파일러와 Java Virtual Machine을 포함하는 자바 프로그래밍의 필수 도구 입니다. Oracle JDK와 Open JDK 두 종류가 있지만 Oracle JDK는 라이센스 문제로 인해 최근에는 Open JDK를 주로 사용하고 있습니다.',
#   'tags': 'Mac'},
#  {'title': '[Mac] 개발환경 구성 필수 요소',
#   'href': 'https://blog.hossam.kr/2023/07/12/Mac-%EA%B0%9C%EB%B0%9C%ED%99%98%EA%B2%BD%EA%B5%AC%EC%84%B1-%ED%95%84%EC%88%98%EC%9A%94%EC%86%8C/',
#   'datetime': '2023-07-12',
#   'text': '직훈교육을 진행하다보면 맥북을 가지고 교육에 참여하는 경우를 종종 보게 됩니다. 하지만 거의 모든 훈련기관은 Windows PC를 강의실에 구비해 놓고 있으며 대부분의 훈련생들은 Windows 환경에서 수업에 참여하기 때문에 맥북을 사용하다 보면 종종 수업 내용과 프로그램 설치 방법에서 차이를 겪으면서 수업 내용을 놓치기 쉽습니다. 컴퓨터 자체에 익숙해서 맥을 능숙하게 다룬다면 수업 내용과의 차이를 스스로 보완할 수 있지만 컴퓨터에 익숙하지 않은 상태에서 단순히 코딩을 하기에 맥이 좋다는 말을 듣고 덜컥 구입하거나 맥북이 이쁘다는 이유로 구입한 경우는 훈련을 진행하면서 무척 난감함을 느끼게 됩니다. 특정 훈련생에게 설치 과정을 별도로 처음부터 알려주기에는 시간 비용이 무척 오래 걸리기 때문입니다. 이 포스팅에서는 MacOS 환경에서 코딩을 진행하고자 할 경우 필수로 설치해야 하는 요소들을 소개합니다.',
#   'tags': 'Mac'}]

# %%
fname = dt.datetime.now().strftime("블로그_글_수집_%y%m%d_%H%M%S.csv")

with open(fname, "w", encoding='utf-8') as f:
    for i, v in enumerate(mydata):
        if i == 0:
            title = "%s\n" % ",".join(list(v.keys()))
            #print(title)
            f.write(title) 

        content = list(v.values())

        for j, w in enumerate(content):
            content[j] = '"%s"' % w.replace('"','\\"')

        f.write("%s\n" % ",".join(content))
