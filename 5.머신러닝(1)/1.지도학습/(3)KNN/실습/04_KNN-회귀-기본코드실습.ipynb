# %% [markdown]
# # KNN 회귀 기본 코드
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

from hossam.util import *
from hossam.plot import *
from hossam.analysis import *
from hossam.regression import *

from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ### [2] 데이터 가져오기

# %%
origin = my_read_excel('https://data.hossam.kr/mldata/fish.xlsx')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   길이      56 non-null     float64
#  1   높이      56 non-null     float64
#  2   두께      56 non-null     float64
#  3   무게      56 non-null     float64
# dtypes: float64(4)
# memory usage: 1.9 KB
# None
#
# 데이터프레임 상위 5개 행
# +----+--------+--------+--------+--------+
# |    |   길이 |   높이 |   두께 |   무게 |
# |----+--------+--------+--------+--------|
# |  0 |    8.4 |   2.11 |   1.41 |    5.9 |
# |  1 |   13.7 |   3.53 |      2 |     32 |
# |  2 |     15 |   3.82 |   2.43 |     40 |
# |  3 |   16.2 |   4.59 |   2.63 |   51.5 |
# |  4 |   17.4 |   4.59 |   2.94 |     70 |
# +----+--------+--------+--------+--------+
#
# 데이터프레임 하위 5개 행
# +----+--------+--------+--------+--------+
# |    |   길이 |   높이 |   두께 |   무게 |
# |----+--------+--------+--------+--------|
# | 51 |     42 |   12.8 |   6.87 |   1100 |
# | 52 |     43 |  11.93 |   7.28 |   1000 |
# | 53 |     43 |  12.51 |   7.42 |   1100 |
# | 54 |   43.5 |   12.6 |   8.14 |   1000 |
# | 55 |     44 |  12.49 |    7.6 |   1000 |
# +----+--------+--------+--------+--------+
#
# 기술통계
# +------+---------+---------+---------+-------+--------+-------+--------+-------+-------+
# |      |   count |    mean |     std |   min |    25% |   50% |    75% |   max |   nan |
# |------+---------+---------+---------+-------+--------+-------+--------+-------+-------|
# | 길이 |      56 | 27.8929 | 9.02167 |   8.4 | 21.825 |  25.3 | 36.625 |    44 |     0 |
# | 높이 |      56 | 7.86214 | 2.87834 |  2.11 |   5.69 |  6.92 |  10.85 |  12.8 |     0 |
# | 두께 |      56 | 4.74554 | 1.77501 |  1.41 |   3.52 | 4.155 |   6.45 |  8.14 |     0 |
# | 무게 |      56 | 382.239 | 347.618 |   5.9 |    120 | 207.5 |  692.5 |  1100 |     0 |
# +------+---------+---------+---------+-------+--------+-------+--------+-------+-------+

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 훈련, 검증 데이터 분리 + 스케일링

# %%
x_train, x_test, y_train, y_test = my_train_test_split(origin, yname='무게', scalling=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((44, 3), (44,), (12, 3), (12,))

# %% [markdown]
# ## #03. KNN 회귀분석
#
# ### [1] 예측 모델 구현
#
# | 파라미터 | 타입 | 설명 | 기본값 |
# |---|---|---|---|
# | n_neighbors | `int` | $k$값 | `5` |
# | weights | `str` | 가중치 적용 여부<br/>-`uniform`: 가중치 사용 안함<br/> -`distance`: 거리의 역수 만큼 가중치 부여 | `uniform` |
# | p | `int` | `1` - 맨하탄 거리 측정<br/>`2` - 유클리디안 거리 측정 | `2` |

# %%
estimator = KNeighborsRegressor(
    n_neighbors=5,
    weights='uniform',
    p=2,
    n_jobs=-1)
estimator.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %% [markdown]
# ### [2] 성능평가

# %%
my_regression_result(estimator, x_train, y_train, x_test, y_test)
# Out:
# [회귀분석 성능평가]
# +-------------------------------+--------------+--------------+
# |                               |   훈련데이터 |   검증데이터 |
# |-------------------------------+--------------+--------------|
# | 결정계수(R2)                  |     0.982478 |     0.986901 |
# | 평균절대오차(MAE)             |      29.6423 |         27.8 |
# | 평균제곱오차(MSE)             |      2060.57 |      1545.59 |
# | 평균오차(RMSE)                |      45.3935 |       39.314 |
# | 평균 절대 백분오차 비율(MAPE) |      22.2748 |      6.20356 |
# | 평균 비율 오차(MPE)           |     -14.4093 |    -0.875183 |
# +-------------------------------+--------------+--------------+
#
# [학습곡선]

# %% [markdown]
# ## #04. 2차항 생성 후 분석 수행
#
# ### [1] 2차항 생성

# %%
df = my_poly_features(origin, ignore=['무게'])
my_pretty_table(df.head())
# Out:
# +----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------+--------+
# |    |   길이 |   높이 |   두께 |   길이^2 |   길이 높이 |   길이 두께 |   높이^2 |   높이 두께 |   두께^2 |   무게 |
# |----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------+--------|
# |  0 |    8.4 |   2.11 |   1.41 |    70.56 |      17.724 |      11.844 |   4.4521 |      2.9751 |   1.9881 |    5.9 |
# |  1 |   13.7 |   3.53 |      2 |   187.69 |      48.361 |        27.4 |  12.4609 |        7.06 |        4 |     32 |
# |  2 |     15 |   3.82 |   2.43 |      225 |        57.3 |       36.45 |  14.5924 |      9.2826 |   5.9049 |     40 |
# |  3 |   16.2 |   4.59 |   2.63 |   262.44 |      74.358 |      42.606 |  21.0681 |     12.0717 |   6.9169 |   51.5 |
# |  4 |   17.4 |   4.59 |   2.94 |   302.76 |      79.866 |      51.156 |  21.0681 |     13.4946 |   8.6436 |     70 |
# +----+--------+--------+--------+----------+-------------+-------------+----------+-------------+----------+--------+

# %% [markdown]
# ### [2] 훈련, 검증 데이터 분리 + 스케일링

# %%
x_train, x_test, y_train, y_test = my_train_test_split(df, yname = '무게',scalling=True)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((44, 9), (12, 9), (44,), (12,))

# %% [markdown]
# ### [3] 예측 모델 구현

# %%
estimator = KNeighborsRegressor(
    n_neighbors=5,
    weights='uniform',
    p=2,
    n_jobs=-1)
estimator.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %% [markdown]
# ### [4] 성능평가

# %%
my_regression_result(estimator, x_train, y_train, x_test, y_test)
# Out:
# [회귀분석 성능평가]
# +-------------------------------+--------------+--------------+
# |                               |   훈련데이터 |   검증데이터 |
# |-------------------------------+--------------+--------------|
# | 결정계수(R2)                  |     0.983136 |     0.980358 |
# | 평균절대오차(MAE)             |      28.7877 |         33.9 |
# | 평균제곱오차(MSE)             |      1983.18 |      2317.53 |
# | 평균오차(RMSE)                |      44.5329 |      48.1408 |
# | 평균 절대 백분오차 비율(MAPE) |      22.0807 |      7.36178 |
# | 평균 비율 오차(MPE)           |     -14.4965 |      1.49958 |
# +-------------------------------+--------------+--------------+
#
# [학습곡선]

# %% [markdown]
# ## #04. 모듈화 기능 확인
#
# ### [1] KNN 회귀

# %%
my_knn_regression(x_train, y_train, x_test, y_test)
# Out:
# KNeighborsRegressor의 n_jobs 설정됨
# KNeighborsRegressor {'n_neighbors': [3, 5, 7], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan']}
# [교차검증 TOP5]
# +----+-----------+---------------+-----------+-------------------+
# |    | weights   |   n_neighbors | metric    |   mean_test_score |
# |----+-----------+---------------+-----------+-------------------|
# |  7 | distance  |             3 | manhattan |          0.972923 |
# |  1 | distance  |             3 | euclidean |          0.972423 |
# |  3 | distance  |             5 | euclidean |          0.968397 |
# |  6 | uniform   |             3 | manhattan |          0.967457 |
# |  9 | distance  |             5 | manhattan |           0.96648 |
# +----+-----------+---------------+-----------+-------------------+
#
# [Best Params]
# {'weights': 'distance', 'n_neighbors': 3, 'metric': 'manhattan'}
#
# [회귀분석 성능평가]
# +-------------------------------+--------------+--------------+
# |                               |   훈련데이터 |   검증데이터 |
# |-------------------------------+--------------+--------------|
# | 결정계수(R2)                  |            1 |     0.989254 |
# | 평균절대오차(MAE)             |            0 |      25.8551 |
# | 평균제곱오차(MSE)             |            0 |      1267.95 |
# | 평균오차(RMSE)                |            0 |      35.6082 |
# | 평균 절대 백분오차 비율(MAPE) |            0 |      6.47138 |
# | 평균 비율 오차(MPE)           |            0 |      2.47924 |
# +-------------------------------+--------------+--------------+
#
# [학습곡선]
# +----+------------+------------+-------------+
# |    | 종속변수   | 독립변수   |         VIF |
# |----+------------+------------+-------------|
# |  0 | 무게       | 길이       |     4666.23 |
# |  1 | 무게       | 높이       |     7788.42 |
# |  2 | 무게       | 두께       |     7565.13 |
# |  3 | 무게       | 길이^2     |      188326 |
# |  4 | 무게       | 길이 높이  | 1.35281e+06 |
# |  5 | 무게       | 길이 두께  |      186885 |
# |  6 | 무게       | 높이^2     |      359211 |
# |  7 | 무게       | 높이 두께  |      590745 |
# |  8 | 무게       | 두께^2     |      176151 |
# +----+------------+------------+-------------+
# KNeighborsRegressor(metric='manhattan', n_jobs=-1, n_neighbors=3,
#                     weights='distance')

# %% [markdown]
# ### [2] 지금까지의 모든 예측 모형 비교

# %%
my_regression(x_train, y_train, x_test, y_test)
# Out:
# LinearRegression의 n_jobs 설정됨
# LinearRegression {}
# Ridge의 random_state 설정됨
# Ridge {}
# Lasso의 random_state 설정됨
# Lasso {}
# KNeighborsRegressor의 n_jobs 설정됨
# KNeighborsRegressor {}
# DecisionTreeRegressor의 random_state 설정됨
# DecisionTreeRegressor {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']}
# +-----------------------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# |                       |   결정계수(R2) |   평균절대오차(MAE) |   평균제곱오차(MSE) |   평균오차(RMSE) |   평균 절대 백분오차 비율(MAPE) |   평균 비율 오차(MPE) |
# |-----------------------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------|
# | LinearRegression      |        0.88922 |             59.9979 |               13071 |          114.329 |                         16.0658 |             -0.620989 |
# | Lasso                 |       0.987597 |             26.1655 |             1463.46 |          38.2552 |                          6.4169 |              -2.25938 |
# | Ridge                 |       0.987765 |              26.179 |             1443.59 |          37.9946 |                         6.90009 |              -3.32333 |
# | DecisionTreeRegressor |       0.989445 |               24.25 |             1245.42 |          35.2905 |                         6.76025 |               1.89843 |
# | KNeighborsRegressor   |       0.980358 |                33.9 |             2317.53 |          48.1408 |                         7.36178 |               1.49958 |
# +-----------------------+----------------+---------------------+---------------------+------------------+---------------------------------+-----------------------+
# {'LinearRegression': LinearRegression(n_jobs=-1),
#  'Lasso': Lasso(random_state=1234),
#  'Ridge': Ridge(random_state=1234),
#  'DecisionTreeRegressor': DecisionTreeRegressor(criterion='absolute_error', random_state=1234),
#  'KNeighborsRegressor': KNeighborsRegressor(n_jobs=-1)}
